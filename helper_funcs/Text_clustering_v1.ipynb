# %%
import numpy as np
import sklearn.cluster
from Levenshtein import distance
import pickle

# %%
with open("./progress/wrangled/generic_name_unique.txt", "rb") as fp:   # Unpickling
    generic_name_unique = pickle.load(fp)

# %%
generic_name_unique
# Out:
# ['CHROMIUM PICOLINATE',
#  'FOSAPREPITANT DIMEGLUMINE',
#  'PALIPERIDONE PALMITATE',
#  'AZATHIOPRINE SODIUM',
#  'ST JOHNS WORT',
#  'RITUXIMAB',
#  'DARBEPOETIN ALFA',
#  'BURN RELIEF',
#  'ACETAMINOPHEN ASPIRIN (NSAID) AND CAFFEINE',
#  'MELALEUCA',
#  'BORAGE OIL',
#  'ZICONOTIDE',
#  'DIPHENHYDRAMINE CITRATE AND IBUPROFEN',
#  'MAGNESIUM SULFATE',
#  'ZINC',
#  'CAIRINA MOSCHATA HEART/LIVER AUTOLYSATE',
#  'NITROFURANTOIN MONOHYDRATE AND NITROFURANTOIN MACROCRYSTALLINE',
#  'CHARCOAL ACTIVATED',
#  'LIDOCAINE HYDROCHLORIDEEPINEPHRINE BITARTRATE',
#  'FULVESTRANT',
#  'CHORIONIC GONADOTROPIN',
#  'BENZOYL PEROXIDE',
#  'ATORVASTATIN CALCIUM FILM COATED',
#  'ATAZANAVIR SULFATE',
#  'QUINUPRISTIN AND DALFOPRISTIN',
#  'GALANTAMINE HYDROBROMIDE',
#  'DIGITALIS',
#  'PROBENECID',
#  'OXYTOCIN',
#  'AMLODIPINE BESYLATE AND VALSARTAN',
#  'VANDETANIB',
#  'CORN AND CALLUS REMOVER KIT',
#  'FLUVOXAMINE MALEATE',
#  'FOXGLOVE',
#  'COUGH SYRUP',
#  'MOXIFLOXACIN',
#  'CLOCORTOLONE PIVALATE',
#  'ACONITUM NAP AESCULUS HIPP FLOS ARSENICUM ALB AVENA BELLADONNA CAMPHORA CINCHONA COFFEA CRUDA CYPRIPEDIUM HYOSCYAMUS IGNATIA PASSIFLORA PULSATILLA VALERIANA',
#  'PROPARACAINE HYDROCHLORIDE',
#  'PSEUDOEPHEDRINE HCL',
#  'CYPROHEPTADINE HYDROCHLORIDE',
#  'AVENA SATIVA LOBELIA INFLATA CACTUS GRANDIFLORUS TABACUM GELSEMIUM SEMPERVIRENS SELENIUM METALLICUM STAPHYSAGRIA VANADIUM METALLICUM',
#  'CHLORAL HYDRATE',
#  'EPIRUBICIN HYDROCHLORIDE',
#  'DONEPEZIL HYDROCHLORIDE',
#  'ALFENTANIL HYDROCHLORIDE',
#  'FENOPROFEN CALCIUM',
#  'RALTEGRAVIR',
#  'IBRITUMOMAB TIUXETAN',
#  'INTERLEUKIN-5',
#  'BENZTROPINE',
#  'PETROLEUM',
#  'SIMETHICONE',
#  'ATENOLOL',
#  'TERBINAFINE HYDROCHLORIDE',
#  'FENTANYL',
#  'RIFAXIMIN',
#  'PILOCARPINE HYDROCHLORIDE',
#  'ONE STEP WART REMOVER',
#  'DILTIAZEM HCL',
#  'LIDOCAINE 5% CREAM',
#  'BERACTANT',
#  'VORINOSTAT',
#  'LOPERAMIDE HYDROCHLORIDE AND DIMETHICONE',
#  'CEVIMELINE',
#  'PHENOBARBITAL HYOSCYAMINE SULFATE ATROPINE SULFATE SCOPOLAMINE HYDROBROMIDE',
#  'POTASSIUM CHLORIDE',
#  'HYDROXYETHYL STARCH 130/0',
#  'DOXYCYCLINE HYCLATE',
#  'GLYBURIDE',
#  'PREDNISOLONE',
#  'MOISTURE ABSORBING MICONAZORBAF ANTIFUNGAL POWDER',
#  'DICLOXACILLIN SODIUM',
#  'ABCIXIMAB',
#  'BUPRENORPHINE AND NALOXONE',
#  'HYDROXYCHLOROQUINE SULFATE',
#  'BECLOMETHASONE DIPROPIONATE MONOHYDRATE',
#  'ZINC GLUCONATE MENTHA PIPERITA EUPATORIUM PERFOLIATUM FLOWERING TOP SAMBUCUS NIGRA FLOWER MYRRH AND GLYCYRRHIZA GLABRA LEAF',
#  'APRACLONIDINE HYDROCHLORIDE',
#  'PSYLLIUM HYDROPHILIC MUCILLOID',
#  'GADOPENTETATE DIMEGLUMINE',
#  'CAFFEINE MAGNESIUM SALICYLATE',
#  'FLURBIPROFEN',
#  'NIACIN',
#  'TETROFOSMIN',
#  'METFORMIN HYDROCHLORIDE',
#  'LIDOCAINE 0',
#  'DESOGESTREL AND ETHINYL ESTRADIOL',
#  'MENTHOL',
#  'ACONITUM NAPELLUS ARSENICUM ALBUM AVENA SATIVA BELLADONNA CAMPHORA CINCHONA OFFICINALIS COFFEA CRUDA CYPRIPEDIUM PUBESCENS HYOSCYAMUS NIGER IGNATIA AMARA PASSIFLORA INCARNATA PULSATILLA VALERIANA OFFICINALISAESCULUS HIPPOCASTANUM FLOS',
#  'BACITRACIN',
#  'DESLORATADINE AND PSEUDOEPHEDRINE SULFATE',
#  'METHENAMINE HIPPURATE',
#  'MILK THISTLE',
#  'IBUTILIDE FUMARATE',
#  'LUBIPROSTONE',
#  'CARBOXYMETHYLCELLULOSE SODIUM',
#  'FLECAINIDE ACETATE TABLET',
#  'ALKA-SELTZER PLUS DAY AND NIGHT COLD',
#  'ONION EUPATORIUM PERFOLIATUM FLOWERING TOP BUCKWHEAT SYMPLOCARPUS FOETIDUS ROOT SAMBUCUS NIGRA FLOWER TUSSILAGO FARFARA LEAF URTICA DIOICA AND ZINC GLUCONATE',
#  'MEDROXYPROGESTERONE ACETATE',
#  'HYDROCHLOROTHIAZIDE AND TRIAMTERENE',
#  'TAMOXIFEN CITRATE',
#  'METHOTREXATE',
#  'TAMSULOSIN HYDROCHLORIDE',
#  'ALDESLEUKIN',
#  'IBUPROFEN SODIUM',
#  'ALUMINUM HYDROXIDE',
#  'MEDICATED CALLUS REMOVERS EXTRA THICK',
#  'ALBENDAZOLE',
#  'BETHANECHOL CHLORIDE 10 MG',
#  'FAMOTIDINE',
#  'ELETRIPTAN HYDROBROMIDE',
#  'DICLOFENAC',
#  'OLMESARTAN MEDOXOMIL',
#  'HETASTARCH IN SODIUM CHLORIDE',
#  'NYSTATIN CREAM',
#  'SODIUM CHLORIDE CALCIUM CHLORIDE AND POTASSIUM CHLORIDE',
#  'ALBUMIN HUMAN',
#  'DIPHENHYDRAMINE HCL 25 MG',
#  'LACTIC ACID',
#  'FLECAINIDE ACETATE',
#  'LAMIVUDINE AND ZIDOVUDINE',
#  'ATENOLOL AND CHLORTHALIDONE',
#  'MAGNESIUM',
#  'RANIBIZUMAB',
#  'KETOCONAZOLE',
#  'OXACILLIN',
#  'SODIUM NITROPRUSSIDE',
#  'IMIPRAMINE PAMOATE',
#  'ANTIFUNGAL MICONAZOLE POWDER SPRAY',
#  'NITROUS OXIDE',
#  'LABETALOL HCL',
#  'DEXTROAMPHETAMINE SULFATE DEXTROAMPHETAMINE SACCHARATE AMPHETAMINE SULFATE AND AMPHETAMINE ASPARTATE',
#  'TROPICAMIDE',
#  'PRAVASTATIN SODIUM',
#  'ZINC OXIDE',
#  'FERROUS FUMARATE ASCORBIC ACID FOLIC ACID CYANOCOBALAMIN',
#  'INTERLEUKIN-10',
#  'ALMOTRIPTAN MALATE',
#  'ETONOGESTREL',
#  'TOPOTECAN HYDROCHLORIDE',
#  'DEXRAZOXANE',
#  'BENZALKONIUM CHLORIDE',
#  'ECULIZUMAB',
#  'LATANOPROST',
#  'ASPIRIN AND CAFFEINE',
#  'CEFAZOLIN',
#  'TETRABENAZINE',
#  'IVERMECTIN',
#  'HYDROXYUREA',
#  'AGRIMONIA EUPATORIA',
#  'METOPROLOL',
#  'NYSTATIN OINTMENT',
#  'POPULUS TREMULOIDES WHOLE',
#  'RHUBARB',
#  'ENTECAVIR',
#  'THIOTEPA',
#  'SENNA LEAF',
#  'LEVONORGESTREL / ETHINYL ESTRADIOL AND ETHINYL ESTRADIOL',
#  'SORE THROAT SPRAY',
#  'IPRATROPIUM BROMIDE',
#  'CYCLOBENZAPRINE',
#  'AMLODIPINE BESYLATE AND BENAZEPRIL HYDROCHLORIDE',
#  'WHITE PETROLATUM MINERAL OIL',
#  'TRANDOLAPRIL',
#  'TADALAFIL',
#  'MECLIZINE HCL 25MG CHEWABLE TABLETS',
#  'RETAPAMULIN',
#  'ORNITHOGALUM UMBELLATUM HELIANTHEMUM NUMMULARIUM WHOLE IMPATIENS GLANDULIFERA WHOLE PRUNUS CERASIFERA WHOLE AND CLEMATIS VITALBA WHOLE',
#  'STRONTIUM CHLORIDE SR-89',
#  'RANITIDINE',
#  'TOLNAFTATE POWDER SPRAY TALC FREE',
#  'WHITE PETROLATUM',
#  'TENOFOVIR DISOPROXIL FUMARATE',
#  'LENALIDOMIDE',
#  'MALUS PUMILA WHOLE',
#  'QUERCETIN',
#  'DEFEROXAMINE MESYLATE',
#  'DEXTROMETHORPHAN HBR GUAIFENESIN',
#  'OXYBUTYNIN CHLORIDE',
#  'THALLOUS CHLORIDE TL-201',
#  'BACITRACIN ZINC NEOMYCIN POLYMYXIN B',
#  'OLANZAPINE',
#  'AMLODIPINE BESYLATE AND OLMESARTAN MEDOXOMIL',
#  'GLYCERIN HYPROMELLOSE POLYETHYLENE GLYCOL 400',
#  'MOEXIPRIL HYDROCHLORIDE',
#  'VALACYCLOVIR',
#  'DEXTROAMPHETAMINE',
#  'SODIUM CARBONATE',
#  'DAUNORUBICIN HYDROCHLORIDE',
#  'ETOPOSIDE',
#  'MEBROFENIN',
#  'HYDRALAZINE HYDROCHLORIDE AND ISOSORBIDE DINITRATE',
#  'TELMISARTAN AND HYDROCHLOROTHIAZIDE',
#  'DISOPYRAMIDE PHOSPHATE',
#  'MELOXICAM',
#  'ONE STEP CORN REMOVER',
#  'ATOMOXETINE HYDROCHLORIDE',
#  'AVOBENZONE OCTOCRYLENE',
#  'EMTRICITABINE AND TENOFOVIR DISOPROXIL FUMARATE',
#  'ACONITUM NAPELLUS ARSENICUM ALBUM BELLADONNA CALCAREA CARBONICA CARCINOSIN CAUSTICUM GELSEMIUM SEMPERVIRENS LACHESIS MUTUS MERCURIUS VIVUS NITRICUM ACIDUM PHOSPHORUS RHUS TOX',
#  'ETHYL ALCOHOL',
#  'RISPERIDONE',
#  'BISOPROLOL FUMARATE',
#  'CHLORASEPTIC',
#  'DIPHENHYDRAMINE CITRATE IBUPROFEN',
#  'THALLIUM',
#  'ANIDULAFUNGIN',
#  'TETRACAINE HCL',
#  'TOLNAFTATE JOCK ITCH POWDER SPRAY TALC FREE',
#  'ESTRADIOL CYPIONATE',
#  'KENALOG',
#  'FOSINOPRIL SODIUM',
#  'FOSFOMYCIN TROMETHAMINE',
#  'DULOXETINE',
#  'TINIDAZOLE',
#  'PODOFILOX',
#  'RANITIDINE HYDROCHLORIDE',
#  'SILDENAFIL',
#  'NOT APPLICABLE',
#  'LOMUSTINE',
#  'DOCOSANOL',
#  'PANCREATIN',
#  'MEPROBAMATE',
#  ' SYZYGIUM TEREBINTHINIAE URANIUM NIT',
#  'TERBINAFINE',
#  'GUAIFENESIN AND DEXTROMETHORPHAN HYDROBROMIDE',
#  'RASAGILINE MESYLATE',
#  'EPOPROSTENOL SODIUM',
#  'TRAMADOL HYDROCHLORIDE AND ACETAMINOPHEN',
#  'ALUMINUM HYDROXIDE AND MAGNESIUM CARBONATE',
#  'DESOGESTREL/ETHINYL ESTRADIOL AND ETHINYL ESTRADIOL',
#  'LEVETIRACETAM INJECTION',
#  'CILOSTAZOL',
#  'CORTISONE ACETATE',
#  'DULOXETIN HYDROCHLORIDE',
#  'BILBERRY',
#  'PIOGLITAZONE AND GLIMEPIRIDE',
#  'HYPROMELLOSES AND CARBOXYMETHYLCELLULOSE SODIUM',
#  'SALSALATE',
#  'GUAIFENESIN AND PSEUDOEPHEDRINE HYDROCHLORIDE',
#  'TEMAZEPAM',
#  'AZITHROMYCIN',
#  'VITAMIN A ASCORBIC ACID CHOLECALCIFEROL ',
#  'POTASSIUM CITRATE',
#  'HALOPERIDOL DECANOATE',
#  'TRIHEXYPHENIDYL HYDROCHLORIDE',
#  'AZELASTINE HCL',
#  'OXYBUTYNIN',
#  'ALFUZOSIN HCL',
#  'APOMORPHINE HYDROCHLORIDE',
#  'GEFITINIB',
#  'DICLOFENAC POTASSIUM',
#  'ETANERCEPT',
#  'MITOTANE',
#  'ANALGESIC',
#  'DROSPIRENONE AND ESTRADIOL',
#  'DIPHENHYDRAMINE HCL IBUPROFEN',
#  'SITAGLIPTIN',
#  'TIGECYCLINE',
#  'CLEMASTINE FUMARATE',
#  'ETODOLAC',
#  'SODIUM PHOSPHATE',
#  'TETRAHYDROZOLINE HCL',
#  'CODEINE PHOSPHATE AND GUAIFENESIN',
#  'PAROXETINE HYDROCHLORIDE HEMIHYDRATE',
#  'CALCIFEDIOL',
#  'HYDROCODONE BITARTRATE',
#  'ALCOHOL 68%',
#  'PROTAMINE SULFATE',
#  'VALPROATE SODIUM',
#  'ISONIAZID',
#  'ISOPROPYL ALCOHOL',
#  'AESCULUS X CARNEA WHOLE',
#  'ANTIFUNGAL LIQUID CONTINUOUS SPRAY',
#  'MAGNESIUM OXIDE',
#  'HYDROCODONE BITARTRATE AND HOMATROPINE METHYLBROMIDE',
#  'IPILIMUMAB',
#  'CAMPHOR (SYNTHETIC) AND MENTHOL',
#  'VANCOMYCIN HCL',
#  'CHLORZOXAZONE',
#  'DEXTROMETHORPHAN HBR AND GUIAFENESIN',
#  'CEFOXITIN',
#  'FLUTICASONE PROPIONATE AND SALMETEROL',
#  'BURN RELIEF SPRAY',
#  'PINDOLOL',
#  'DOPAMINE HCL',
#  'ACETAMINOPHEN ASPIRIN CAFFEINE',
#  'LIOTHYRONINE SODIUM',
#  'ORLISTAT',
#  'SODIUM LACTATE',
#  'VINCRISTINE SULFATE',
#  'ARSENICUM ALBUM CALCAREA CARBONICA IGNATIA AMARA KALI CARBONICUM LACHESIS MUTUS NATRUM MURIATICUM PHOSPHORUS PULSATILLA STAPHYSAGRIA',
#  'LANREOTIDE ACETATE',
#  'ROTIGOTINE',
#  'ZINC CHLORIDE',
#  'POTASSIUM BROMIDE',
#  'BUTALBITAL ASPIRIN AND CAFFEINE',
#  'LOPINAVIR AND RITONAVIR',
#  'POTASSIUM BICARBONATE',
#  'VARENICLINE TARTRATE',
#  'NORETHINDRONE ACETATE',
#  'MITOXANTRONE',
#  'HYDROCORTISONE SODIUM SUCCINATE',
#  'POLYETHYLENE GLYCOL 400 AND PROPYLENE GLYCOL',
#  'SODIUM CHLORIDE POTASSIUM CHLORIDE AND CALCIUM CHLORIDE',
#  'VIGABATRIN',
#  'NORETHINDRONE',
#  'AMOXICILLIN',
#  'ANTI-FUNGAL POWDER MICONAZOLE NITRATE',
#  'INSULIN GLARGINE',
#  'ESTRADIOL AND NORETHINDRONE ACETATE',
#  'CEFIXIME',
#  'OLSALAZINE SODIUM',
#  'BENZTROPINE MESYLATE',
#  'CLINDAMYCIN',
#  'MECLIZINE HYDROCHLORIDE',
#  '0XYGEN',
#  'OXYMORPHONE HYDROCHLORIDE',
#  'AVOBENZONE HOMOSALATE OCTISALATE OCTOCRYLENE OXYBENZONE',
#  'INFLUENZINUM 9C',
#  'BENAZEPRIL HYDROCHLORIDE',
#  '4',
#  'ABACAVIR',
#  'CEFADROXIL',
#  'HYALURONATE SODIUM',
#  'TOPOTECAN',
#  'TIPRANAVIR',
#  'DEXTROMETHORPHAN HYDROBROMIDE AND PROMETHAZINE HYDROCHLORIDE',
#  'CASTANEA SATIVA WHOLE',
#  'BUMETANIDE',
#  'HYDROXYZINE PAMOATE',
#  'ETHINYL ESTRADIOL AND LEVONORGESTREL',
#  ' MET',
#  'PREDNISONE',
#  'BETAXOLOL',
#  'SORAFENIB',
#  'SULFAMETHOXAZOLE AND TRIMETHOPRIM',
#  'BLEOMYCIN',
#  'TRIPTORELIN PAMOATE',
#  'PYRIDOXINE HYDROCHLORIDE',
#  'RIBAVIRIN',
#  'CHLOROTHIAZIDE SODIUM',
#  'FLUTICASONE PROPIONATE',
#  'CEFAZOLIN SODIUM',
#  'BECLOMETHASONE DIPROPIONATE',
#  'MELPHALAN USP 2 MG',
#  'ILEX AQUIFOLIUM WHOLE',
#  'LANTHANUM CARBONATE',
#  'FELBAMATE',
#  'VERAPAMIL HYDROCHLORIDE',
#  'ISRADIPINE',
#  'IMATINIB MESYLATE',
#  'GEMIFLOXACIN MESYLATE',
#  'ALUMINUM HYDROXIDE AND MAGNESIUM TRISILICATE',
#  'DIATRIZOATE MEGLUMINE AND DIATRIZOATE SODIUM',
#  'IBANDRONATE SODIUM',
#  'NEPAFENAC',
#  'AMPHETAMINE SULFATE',
#  'INTERFERON (SUIS)',
#  'BALANCED SALT SOLUTION ENRICHED WITH BICARBONATE DEXTROSE AND GLUTATHIONE',
#  'PANITUMUMAB',
#  'TRIAZOLAM',
#  'TOBRAMYCIN AND DEXAMETHASONE',
#  'SCLERANTHUS ANNUUS WHOLE',
#  'BACITRACIN ZINC NEOMYCIN SULFATE POLYMYXIN B SULFATE',
#  'PEGINTERFERON ALFA-2B',
#  'PANTOPRAZOLE SODIUM',
#  'OXYCODONE HYDROCHLORIDE',
#  'CHOLESTEROL',
#  'CALCIPOTRIENE',
#  'ESTAZOLAM',
#  'LEVETIRACETAM',
#  'FOOT ODOR CONTROL SPRAY',
#  'PROPYLTHIOURACIL',
#  'PIOGLITAZONE HYDROCHLORIDE',
#  'METRONIDAZOLE',
#  'DIPRIDAMOLE',
#  'ALOE ARSENICUM ALB',
#  'CHERYLEE MD SENSITIVE SKIN CARE TRUELIPIDS RELIEVE AND PROTECT OINTMENT',
#  'FLUDARABINE PHOSPHATE',
#  'DIPHENOXYLATE HYDROCHLORIDE AND ATROPINE SULFATE',
#  'AQUAFLORA',
#  'METOLAZONE',
#  'ZINC GLUCONATE ROSA CANINA LEAF AND ECHINACEA PURPUREA',
#  'MULTIVITAMIN/MINERAL',
#  ' RATANHIA VIPERA BERUS AESCULUS HIPP',
#  'LOTEPREDNOL ETABONATE AND TOBRAMYCIN',
#  'PSEUDOEPHEDRINE HYDROCHLORIDE',
#  'DOBUTAMINE HYDROCHLORIDE',
#  'BIMATOPROST',
#  'PHENYTOIN SODIUM',
#  'CITRIC ACID MONOHYDRATE',
#  'POLYETHYLENE GLYCOL (3350)',
#  'TRETINOIN',
#  'FUROSEMIDE',
#  'BISACODYL',
#  'FLUDROCORTISONE ACETATE',
#  'DOCETAXEL',
#  'PIMECROLIMUS',
#  'SUMATRIPTAN SUCCINATE',
#  'PERPHENAZINE',
#  'FLUVASTATIN',
#  'TRIFLURIDINE',
#  'BOSENTAN',
#  'PAMIDRONATE DISODIUM',
#  'ISOSORBIDE MONONITRATE',
#  'CITALOPRAM HYDROBROMIDE',
#  'ANTIFUNGAL MICONAZOLE POWDER JOCK ITCH SPRAY',
#  'EZETIMIBE AND SIMVASTATIN',
#  'OLOPATADINE HYDROCHLORIDE OPHTHALMIC SOLUTION',
#  'PRAMIPEXOLE DIHYDROCHLORIDE',
#  'ROSUVASTATIN CALCIUM',
#  'GUAIFENESIN',
#  'CARBAMIDE PEROXIDE',
#  'GLATIRAMER',
#  'DEXTROMETHORPHAN HYDROBROMIDE AND GUAIFENESIN',
#  'DIHYDROERGOTAMINE MESYLATE',
#  'INTERLEUKIN-3',
#  '5-HYDROXYTRYPTOPHAN',
#  'ANTIFUNGAL MICONAZOLE LIQUID CONTINUOUS SPRAY',
#  'TRANDOLAPRIL TABLETS',
#  'PROPANTHELINE BROMIDE',
#  'DESOXIMETASONE',
#  'NEOMYCIN SULFATE POLYMYXIN B SULFATE AND DEXAMETHASONE',
#  'CRANBERRY',
#  'ACYCLOVIR SODIUM',
#  'FOSCARNET SODIUM',
#  'PENCICLOVIR',
#  'SIMETHICONE AND CALCIUM CARBONATE',
#  'AMANTADINE',
#  'DEXTROSE MONOHYDRATE',
#  'DOXAZOSIN',
#  'ONE STEP CLEAR WART REMOVER',
#  'AMINOSALICYLIC ACID',
#  'URSODIOL',
#  'ULMUS MINOR WHOLE',
#  'CARBAMIDE PEROXIDE 6',
#  'LINEZOLID',
#  'BENZOCAINE',
#  'CYANOCOBALAMINE',
#  'TOLVAPTAN',
#  'BETAMETHASONE ACETATE AND BETAMETHASONE SODIUM PHOSPHATE',
#  'RIVASTIGMINE',
#  'EMOLLIENT',
#  'LOXAPINE SUCCINATE',
#  'CLADRIBINE',
#  'CHLORDIAZEPOXIDE HYDROCHLORIDE AND CLIDINIUM BROMIDE',
#  'PORK COLLAGEN',
#  '6 MG',
#  'PYRANTEL PAMOATE',
#  'DEXAMETHASONE 1',
#  'NICOTINE',
#  'CONJUGATED ESTROGENS AND MEDROXYPROGESTERONE ACETATE',
#  'MICONAZORB AF POWDER',
#  'POLYVINYL ALCOHOL POVIDONE',
#  'GADOVERSETAMIDE',
#  'METOCLOPRAMIDE HYDROCHLORIDE',
#  'ISOSORBIDE DINITRATE',
#  'APIS MELLIFICA BERBERIS VULGARIS HELLEBORUS NIGER JUNIPERUS COMMUNIS PRUNUS SPINOSA STROPHANTHUS HISPIDUS TARAXACUM OFFICINALE UVA-URSI',
#  'PEGFILGRASTIM',
#  'LACTULOSE',
#  'ARSENIC TRIOXIDE',
#  'TERBUTALINE SULFATE',
#  'TELMISARTAN',
#  'AMINOCAPROIC ACID',
#  'CEPHALEXIN',
#  'GADOTERATE MEGLUMINE',
#  'PENTOXIFYLLINE',
#  'AVENA SATIVA',
#  'LABETALOL',
#  'FLUOROURACIL',
#  'DOCUSATE SODIUM AND SENNOSIDES',
#  'SILVER SULFADIAZINE',
#  'MENOTROPINS',
#  'TRANDOLAPRIL AND VERAPAMIL HYDROCHLORIDE',
#  'PROGESTERONE',
#  'BENZONATATE',
#  'BARIUM SULFATE',
#  'TIOCONAZOLE',
#  'OLANZAPINE PAMOATE',
#  'LANOLIN',
#  'SENNOSIDES',
#  'MESALAMINE',
#  'NEFAZODONE HYDROCHLORIDE',
#  'SENNA',
#  'AMOXICILLIN AND CLAVULANATE POTASSIUM',
#  'CYCLOSPORINE',
#  'PANCRELIPASE',
#  'PILOCARPINE HYROCHLORIDE',
#  'SUFENTANIL CITRATE',
#  'ATHLETE S FOOT SPRAY',
#  'CALCIUM ACETATE',
#  'IRON SUPPLEMENT THERAPY',
#  'POVIDONE-IODINE',
#  'METHAZOLAMIDE',
#  'NEVIRAPINE',
#  'TROSPIUM CHLORIDE',
#  'WART REMOVER MEDICATED DISCS',
#  'TETRACYCLINE HYDROCHLORIDE',
#  'PIOGLITAZONE AND METFORMIN HYDROCHLORIDE',
#  'ALEMTUZUMAB',
#  'HYDROXYZINE',
#  'FOLLITROPIN ALFA',
#  'ACETYLCYSTEINE',
#  'GADODIAMIDE',
#  'AMPICILLIN SODIUM AND SULBACTAM SODIUM',
#  'LEVOCETIRIZINE DIHYDROCHLORIDE',
#  'CALLUS REMOVERS',
#  'TETRAKIS(2-METHOXYISOBUTYLISOCYANIDE)COPPER(I) TETRAFLUOROBORATE',
#  'FOSINOPRIL',
#  'DIAZEPAM',
#  'PHENOBARBITAL',
#  'ABATACEPT',
#  'ZOLPIDEM TARTRATE',
#  'IRBESARTAN AND HYDROCHLOROTHIAZIDE',
#  '5 MCG',
#  'TRIAMTERENE AND HYDROCHLOROTHIAZIDE',
#  'IBUPROFEN LYSINE',
#  'NAFTIFINE HYDROCHLORIDE',
#  'CEFOTAXIME',
#  'SUCCIMER',
#  'COLISTIMETHATE',
#  'ACITRETIN',
#  'NORETHINDRONE ACETATE/ETHINYL ESTRADIOL',
#  '5%',
#  'HYOSCYAMINE SULFATE METHENAMINE METHYLENE BLUE PHENYL SALICYLATE AND SODIUM PHOSPHATE MONOBASIC MONOHYDRATE',
#  'WART REMOVER GEL PEN',
#  'OXYCODONE HYDROCHLORIDE AND ACETAMINOPHEN',
#  'ANTI-FUNGAL POWDER MICONAZOLE NITRATE TALC FREE',
#  'CYCLOPHOSPHAMIDE',
#  'DHEA (DEHYDROEPIANDROSTERONE)',
#  'THALIDOMIDE',
#  'LOSARTAN POTASSIUM',
#  'ROYAL JELLY',
#  'RAMIPRIL',
#  'LEUCOVORIN CALCIUM',
#  'CEFPROZIL',
#  'NALOXONE HYDROCHLORIDE',
#  'BASILIXIMAB',
#  'POVIDONE',
#  'CHORIOGONADOTROPIN ALFA',
#  'BIOTIN',
#  'MILK OF MAGNESIA',
#  'NEOSTIGMINE METHYLSULFATE',
#  'FOSPHENYTOIN SODIUM',
#  'ESOMEPRAZOLE MAGNESIUM',
#  'INTERFERON BETA-1A',
#  'METHYLERGONOVINE MALEATE',
#  'ENEMA',
#  'LIDOCAINE PATCH 4%',
#  'TETRACAINE HYDROCHLORIDE',
#  'LOSARTAN POTASSIUM AND HYDROCHLOROTHIAZIDE TABLETS',
#  'ACETAMINOPHEN GUAIFENESIN AND PHENYLEPHRINE HYDROCHLORIDE',
#  'DIMETHYL SULFOXIDE',
#  'DEADLY NIGHTSHADE',
#  'MICONAZOLE NITRATE ANTIFUNGAL POWDER SPRAY',
#  'GUAIFENESIN AND DEXTROMETHORPHAN HBR',
#  'POLYETHYLENE GLYCOL 3350 SODIUM SULFATE SODIUM CHLORIDE POTASSIUM CHLORIDE ASCORBIC ACID SODIUM ASCORBATE',
#  'METHYLPREDNISOLONE SODIUM SUCCINATE',
#  'BUSULFAN',
#  'CEFADROXIL MONOHYDRATE',
#  'MYCOPHENOLATE MOFETIL HYDROCHLORIDE',
#  'AMLODIPINE BESYLATE AND ATORVASTATIN CALCIUM',
#  'NORETHINDRONE ACETATE AND ETHINYL ESTRADIOL',
#  'ALENDRONATE SODIUM AND CHOLECALCIFEROL',
#  'BUPIVACAINE HYDROCHLORIDE',
#  'RUFINAMIDE',
#  'RASBURICASE',
#  'SELENIUM SULFIDE',
#  'NICOTINE POLACRILEX',
#  'PROPOFOL',
#  'HYDROCODONE BITATRATE AND ACETAMINOPHEN',
#  'CLONAZEPAM',
#  'INDIUM IN -111 PENTETREOTIDE',
#  'RIMEXOLONE',
#  'FOSINOPIRL SODIUM',
#  'SAW PALMETTO',
#  'DACARBAZINE',
#  'HYDROCORTISONE ACETATE',
#  'PREDNISOLONE ACETATE',
#  'EXEMESTANE',
#  'VITAMIN A',
#  'INSULIN HUMAN',
#  'FLUOXYMESTERONE',
#  'CROMOLYN',
#  'DORZOLAMIDE HYDROCHLORIDE',
#  'VALPROIC ACID',
#  'NA',
#  'METHYLNALTREXONE BROMIDE',
#  'AMIKACIN SULFATE',
#  'REGULAR STRENGTH ASPIRIN',
#  'ALCOHOL 62%',
#  'METHIMAZOLE',
#  'DORIPENEM',
#  'DOCUSATE SODIUM 100 MG',
#  'PORACTANT ALFA',
#  'CARTEOLOL HYDROCHLORIDE',
#  'QUININE SULFATE',
#  'HYDROCODONE BITARTRATE ACETAMINOPHEN',
#  'CAPECITABINE',
#  'CAPREOMYCIN',
#  'MYCOPHENOLATE MOFETIL',
#  'BETAMETHASONE',
#  'SUNITINIB MALATE',
#  'CARMUSTINE',
#  'IBUPFROFEN',
#  'PENICILLIN G PROCAINE',
#  'VASOPRESSIN',
#  'LIDOCAINE 5%',
#  'ILOPROST',
#  'CITALOPRAM TABLETS',
#  'OLANZAPINE AND FLUOXETINE HYDROCHLORIDE',
#  'CEFDITOREN PIVOXIL',
#  'BUSPIRONE HYDROCHLORIDE',
#  'TACROLIMUS CAPSULES',
#  'PYRETHRUM EXTRACT AND PIPERONYL BUTOXIDE',
#  'ERLOTINIB HYDROCHLORIDE',
#  'PRAMIPEXOLE',
#  'FLAVOXATE HYDROCHLORIDE',
#  'ATOVAQUONE',
#  'CLORAZEPATE DIPOTASSIUM',
#  'COLESTIPOL HYDROCHLORIDE',
#  'HOTTONIA PALUSTRIS WHOLE',
#  'LAMIVUDINE',
#  'CEFPODOXIME PROXETIL',
#  'METHYL SALICYLATE MENTHOL AND CAMPHOR (SYNTHETIC)',
#  'METHYLPREDNISOLONE',
#  'LITHIUM BROMATUM',
#  'FENTANYL TRANSDERMAL SYSTEM',
#  '5 MG',
#  'BETHANECHOL CHLORIDE 50 MG',
#  'TIAGABINE HYDROCHLORIDE',
#  'FAMCICLOVIR',
#  'OXAZEPAM',
#  'DEXTROMETHORPHAN HYDROBROMIDE AND MENTHOL',
#  'IRON',
#  'CARPINUS BETULUS WHOLE',
#  'ESOMEPRAZOLE SODIUM',
#  'CLOBAZAM',
#  'SODIUM PHENYLACETATE AND SODIUM BENZOATE',
#  'LIQUID WART REMOVER',
#  'OMEPRAZOLE MAGNESIUM',
#  'DILTIAZEM HYDROCHLORIDE EXTENDED-RELEASE TABLETS',
#  'PEGINTERFERON ALFA-2A',
#  'MANGANESE CHLORIDE',
#  'BACILLUS SUBTILIS',
#  'FAGUS SYLVATICA WHOLE',
#  'METHYLPHENIDATE HYDROCHLORIDE',
#  'COD LIVER OIL',
#  'POLYETHYLENE GLYCOL 3350',
#  'SODIUM CHLORIDE SODIUM LACTATE POTASSIUM CHLORIDE CALCIUM CHLORIDE',
#  '-CAROTENE ASCORBIC ACID CHOLECALCIFEROL ',
#  'PURIFIED WATER',
#  'BUDESONIDE',
#  'ONE-STEP CORN REMOVER CLEAR',
#  'ORPHENADRINE CITRATE',
#  'ST',
#  'OLEA EUROPAEA WHOLE',
#  'OXYGEN',
#  'MEBENDAZOLE',
#  'AVENA SATIVA BARYTA CARBONICA CARDUUS MAR DAMIANA HAMAMELIS VIRG HEPAR KOREAN GINSENG NUPHAR ORCHITINUM PHOSPHORICUM ACIDUM POPULUS TREM SABAL SERULATA SELENIUM METALLICUM TESTOSTERONE',
#  'FLUNISOLIDE',
#  'THIAMINE HYDROCHLORIDE RIBOFLAVIN 5 PHOSPHATE SODIUM PYRIDOXINE HYDROCHLORIDE DEXPANTHENOL AND NIACINAMIDE',
#  'PHENTERMINE HYDROCHLORIDE',
#  'SULFASALAZINE',
#  'FLURAZEPAM HYDROCHLORIDE',
#  'LOPERAMIDE HCL',
#  'NAPROXEN SODIUM COATED TABLETS',
#  'TRANYLCYPROMINE SULFATE',
#  'GLUTAMINE',
#  'LIDOCAINE HYDROCHLORIDE',
#  'RIZATRIPTAN BENZOATE',
#  'AMLODIPINE BESYLATE',
#  'FERROUS SULFATE',
#  'NITROFURANTOIN (MONOHYDRATE/MACROCRYSTALS)',
#  'GLYCERIN',
#  'FLAXSEED',
#  'ACETAMINOPHEN DEXTROMETHORPHAN HYDROBROMIDE CHLORPHENIRAMINE MALEATE AND PHENYLEPHRINE HYDROCHLORIDE',
#  'MENTHA PIPERITA',
#  'CICLESONIDE',
#  'ENALAPRIL MALEATE AND HYDROCHLOROTHIAZIDE',
#  'CABERGOLINE',
#  'TECHNETIUM TC 99M-LABELED RED BLOOD CELLS',
#  'VITAMINS AND MINERALS',
#  'SODIUM CHLORIDE',
#  'BENAZEPRIL HYDROCHLORIDE AND HYDROCHLOROTHIAZIDE',
#  'THEOPHYLLINE',
#  '(METHYLPHENIDATE HYDROCHLORIDE)',
#  'LORATADINE',
#  'PENTAMIDINE ISETHIONATE',
#  'LOTEPREDNOL ETABONATE',
#  'TIZANIDINE HYDROCHLORIDE',
#  'WART REMOVER GEL',
#  'LINCOMYCIN HYDROCHLORIDE',
#  'AZACITIDINE',
#  'FLUPHENAZINE DECANOATE',
#  'NEOMYCIN',
#  'BLACK COHOSH',
#  'NANDROLONE DECANOATE',
#  'FLUORIDE',
#  ' BRYONIA CACTUS CHELIDONIUM MAJUS CINCHONA CROTALUS HORRIDUS DIGITALIS GLONOINUM KALI CARB',
#  'ZIDOVUDINE',
#  'UROFOLLITROPIN',
#  'INTERLEUKIN-9',
#  'BROMOCRIPTINE MESYLATE',
#  'ALOSETRON HYDROCHLORIDE',
#  'TRAZODONE HYDROCHLORIDE',
#  'NYSTATIN',
#  'NEOMYCIN AND POLYMYXIN B SULFATES AND GRAMICIDIN',
#  'METOPROLOL TARTRATE',
#  'GABAPENTIN',
#  'CHERYLEE MD SENSITIVE SKIN CARE TRUELIPIDS DOUBLE ACTION BOO-BOO BUM',
#  'ATHLETES FOOT POWDER SPRAY TALC FREE',
#  'ADALIMUMAB',
#  'ANTIFUNGAL TOLNAFTATELIQUID CONTINUOUS SPRAY',
#  'CHOLINE MAGNESIUM TRISALICYLATE',
#  'FINASTERIDE',
#  'BUTALBITAL ACETAMINOPHEN AND CAFFEINE',
#  'SENNOSIDES A AND B',
#  'TUBERCULIN PURIFIED PROTEIN DERIVATIVE',
#  'KETOROLAC TROMETHAMINE',
#  'IRON DEXTRAN',
#  'DESIPRAMINE',
#  'PRAZOSIN HYDROCHLORIDE',
#  'ACETAMINOPHEN AND CODEINE PHOSPHATE',
#  'POVIDONE IODINE',
#  'MEGESTEROL ACETATE',
#  'SALMETEROL XINAFOATE',
#  'SODIUM IODIDE I 123',
#  'NITROFURANTOIN MONOHYDRATE/MACROCRYSTALS',
#  'EFAVIRENZ EMTRICITABINE AND TENOFOVIR DISOPROXIL FUMARATE',
#  'QUINAPRIL',
#  'TIAGABINE',
#  'TEMSIROLIMUS',
#  'BALSALAZIDE DISODIUM',
#  'POLYVINYL ALCOHOL',
#  'MONTELUKAST',
#  'SOMATROPIN',
#  'FLUOCINOLONE ACETONIDE',
#  '-TOCOPHEROL ACETATE DL- THIAMINE MONONITRATE RIBOFLAVIN NIACINAMIDE PYRIDOXINE HYDROCHLORIDE FOLIC ACID CYANOCOBALAMIN CALCIUM CARBONATE FERROUS FUMARATE ZINC OXIDE CUPRIC OXIDE',
#  'LAXATIVE',
#  'CLARITHROMYCIN',
#  'MONTELUKAST SODIUM',
#  'LANSOPRAZOLE',
#  'BACLOFEN',
#  'BUPROPION HYDROCHLORIDE EXTENDED-RELEASE TABLETS (XL)',
#  'BETHANECHOL CHLORIDE',
#  'BUPROPION HYDROCHLORIDE',
#  'ERTAPENEM SODIUM',
#  'FEXOFENADINE HCL',
#  'DOCETAXEL ANHYDROUS',
#  'LIQUID CORN AND CALLUS REMOVER',
#  'MEDICATED CALLUS REMOVERS',
#  'IBUPROFEN',
#  'LOPERAMIDE HYDROCHLORIDE',
#  'MEPERIDINE HCL',
#  'BROSIMUM ACUTIFOLIUM HIMATANTHUS SUCUUBA MANSOA ALLIACEA MINQUARTIA GUIANENSIS PHYLLANTHUS NIRURI PIPER ADUNCUM',
#  'SILVER NITRATE',
#  'ZINC ACETATE ANHYDROUS AND ZINC GLUCONATE',
#  'NASAL SPRAY',
#  'OXYCODONE AND ASPIRIN',
#  'DEXMETHYLPHENIDATE HYDROCHLORIDE',
#  ' BARYTA CARB',
#  'EFAVIRENZ',
#  'BISOPROLOL FUMARATE AND HYDROCHLOROTHIAZIDE',
#  'FLUOCINONIDE',
#  ' URTICA UR',
#  'ESCITALOPRAM',
#  'TERAZOSIN HYDROCHLORIDE',
#  'ALCOHOL',
#  'RALOXIFENE',
#  'MILNACIPRAN HYDROCHLORIDE',
#  'CLONIDINE',
#  'BETHANECHOL CHLORIDE 25 MG',
#  'ACETAMINOPHEN DIPHENHYDRAMINE HYDROCHLORIDE',
#  'AUTOLOGOUS CULTURED CHONDROCYTES',
#  'ARIPIPRAZOLE',
#  'ACETAMINOPHEN CAFFEINE',
#  'ABACAVIR SULFATE AND LAMIVUDINE',
#  'ZINC GLUCONATE EUPATORIUM PERFOLIATUM FLOWERING TOP SAMBUCUS NIGRA FLOWER VALERIAN CHAMOMILE MENTHA PIPERITA MYRRH AND GLYCYRRHIZA GLABRA LEAF',
#  'TIMOLOL',
#  'BEE VENOM',
#  'PITAVASTATIN CALCIUM',
#  'WART REMOVERS',
#  'KETOTIFEN FUMARATE',
#  'QUININE',
#  'MINERAL OIL AND PETROLATUM',
#  'PYRITIONE ZINC',
#  'ERYTHROMYCIN',
#  'CHERYLLEE MD SENSITIVE SKIN CARE TRUELIPIDS TRUELIPS LIP BALM',
#  'METHOCARBAMOL',
#  'ACEBUTOLOL HYDROCHLORIDE',
#  'WART REMOVER GEL TUBE',
#  'CHLORPHENIRAMINE MALEATE AND PSEUDOEPHEDRINE HCL',
#  'INTERLEUKIN-11',
#  'ACETAMINOPHEN DEXTROMETHORPHAN HBR PHENYLEPHRINE HCL',
#  'HYDROCODONE BITARTRATE AND IBUPROFEN',
#  'TIROFIBAN',
#  'GENTAMICIN SULFATE',
#  'PROPAFENONE',
#  'GINKGO BILOBA',
#  'LORAZEPAM',
#  'ECHINACEA ANGUSTIFOLIA HAMAMMELIS VIRGINIANA CALCAREA PHOSPHORICA HYDRASTIS CANADANESIS SENEGA OFFICINALIS SILICEA CONIUM AURUM MURIATICUM NATRONATUM CALCAREA CARBONICA FUCUS VESICULOSUS LACHESIS MUTUS',
#  'CORN REMOVERS',
#  'TESTOSTERONE CYPIONATE',
#  'BUPIVACAINE HYDROCHLORIDE AND EPINEPHRINE BITARTRATE',
#  'DOXEPIN HYDROCHLORIDE',
#  'MOMETASONE FUROATE MONOHYDRATE',
#  'NORGESTIMATE AND ETHINYL ESTRADIOL',
#  'CARBIDOPA',
#  'PRIMIDONE',
#  'FLUCYTOSINE',
#  'ANAGRELIDE HYDROCHLORIDE',
#  'AZELAIC ACID',
#  'AMPHOTERICIN B DIMYRISTOYLPHOSPHATIDYLCHOLINE DL- AND DIMYRISTOYLPHOSPHATIDYLGLYCEROL DL-',
#  'DEFERASIROX',
#  'CALCIUM CARBONATE',
#  'CIDOFOVIR ANHYDROUS',
#  'ADENOSINUM CYCLOPHOSPHORICUM COFFEA CRUDA GLANDULA SUPRARENALIS SUIS HYPOTHALAMUS (BOVINE) KALI PHOSPHORICUM NATRUM MURIATICUM SARSAPARILLA SILICEA TARAXACUM OFFICINALE THYROIDINUM (BOVINE)',
#  'QUERCUS ROBUR WHOLE',
#  'ERGOTAMINE TARTRATE AND CAFFEINE',
#  'CALCITONIN SALMON',
#  'METHYLPREDNISOLONE ACETATE',
#  'FLUTICASONE PROPIONATE AND SALMETEROL XINAFOATE',
#  'AMPICILLIN',
#  'SMALL CORN REMOVERS',
#  'CANDIDA ALBICANS WOOD CREOSOTE SODIUM CHLORIDE AND SULFUR',
#  'QUETIAPINE',
#  'RIFAMPIN',
#  'NORTRIPTYLINE HYDROCHLORIDE',
#  'BENADRYL',
#  'TRASTUZUMAB',
#  'CIDOFOVIR',
#  'SODIUM CHLORIDE CALCIUM CHLORIDE POTASSIUM CHLORIDE',
#  'CHLORHEXIDINE GLUCONATE',
#  'ATROPINE SULFATE',
#  'ASPARAGINASE',
#  'AMIODARONE HCL',
#  'PEGAPTANIB SODIUM',
#  'LANSOPRAZOLE AMOXICILLIN AND CLARITHROMYCIN',
#  'VITAMIN A ACETATE ',
#  'ROBINUL',
#  'BETAMETHASONE DIPROPIONATE',
#  'SUMATRIPTAN SUCCINATE AND NAPROXEN SODIUM',
#  'PAMABROM',
#  'RISEDRONATE SODIUM',
#  'BACITRACIN ZINC',
#  'INTERLEUKIN-8',
#  'CAPSAICIN',
#  'ONDANSETRON HYDROCHLORIDE',
#  'CEVIMELINE HYDROCHLORIDE',
#  'INFLUENZINUM (2017-2018)',
#  'EUPATORIUM PERFOLIATUM FLOWERING TOP AND VISCUM ALBUM LEAF',
#  'CALCIUM GLUCONATE',
#  'MANGANESE',
#  'BRIMONIDINE TARTRATE',
#  'PINUS SYLVESTRIS WHOLE',
#  'SILODOSIN',
#  'METHYLCELLULOSE',
#  'ACETAMINOPHEN DEXTROMETHORPHAN HYDROBROMIDE GUAIFENESIN AND PHENYLEPHRINE HYDROCHLORIDE',
#  'PENTOSTATIN',
#  'SALIX ALBA WHOLE',
#  'MIRTAZAPINE',
#  'MELATONIN',
#  'OXYGEN COMPRESSED',
#  'BUPRENORPHINE HYDROCHLORIDE',
#  'DOPAMINE HYDROCHLORIDE',
#  'HYPERICUM PERF',
#  'RILUZOLE',
#  'POVIONE IODINE',
#  'NIZATIDINE',
#  'FERROUS FUMARATE',
#  'HELIANTHEMUM NUMMULARIUM WHOLE',
#  'ETRAVIRINE',
#  'OCTISALATE AVOBENZONE ENSULIZOLE',
#  'DULOXETINE HYDROCHLORIDE',
#  'ANTICOAGULANT SODIUM CITRATE SOLUTION',
#  'METAXALONE',
#  'LARIX DECIDUA WHOLE',
#  'AZTREONAM',
#  'OMALIZUMAB',
#  'PROMETHAZINE',
#  'DEXTROAMPHETAMINE SULFATE',
#  'OXYMETAZOLINE HYDROCHLORIDE',
#  'FLECAINIDE',
#  'SODIUM SULFACETAMIDE',
#  'SULFUR AND RESORCINOL',
#  'FOSAMPRENAVIR CALCIUM',
#  'AZATHIOPRINE',
#  'DICLOFENAC SODIUM',
#  'SODIUM PHOSPHATE MONOBASIC MONOHYDRATE AND SODIUM PHOSPHATE DIBASIC ANHYDROUS',
#  'OFLOXAXIN',
#  'DICLOFENAC EPOLAMINE',
#  'QUINAPRIL HYDROCHLORIDE AND HYDROCHLOROTHIAZIDE',
#  'COLESEVELAM HYDROCHLORIDE',
#  'PENTOSAN POLYSULFATE SODIUM',
#  'SODIUM BICARBONATE',
#  'WATER',
#  'DACLIZUMAB',
#  'CEFTRIAXONE SODIUM',
#  'ESTROPIPATE',
#  'CROTAMITON',
#  'ALISKIREN HEMIFUMARATE',
#  'NEOMYCIN SULFATE',
#  'JOCK ITCH POWDER',
#  'SUMATRIPTAN AND NAPROXEN SODIUM',
#  'HOMEOPATHIC LIQUID',
#  'CEFTAZIDIME SODIUM',
#  'NORELGESTROMIN AND ETHINYL ESTRADIOL',
#  'EZETIMIBE',
#  'VALGANCICLOVIR HYDROCHLORIDE',
#  'NILOTINIB',
#  'NARATRIPTAN HYDROCHLORIDE',
#  'METOCLOPRAMIDE',
#  'FOLLICULINUM OOPHORINUM',
#  'NELFINAVIR MESYLATE',
#  'NATALIZUMAB',
#  'NISOLDIPINE',
#  'FLUORESCEIN SODIUM',
#  'LIDOCAINE',
#  'BROMUS RAMOSUS WHOLE',
#  'ECONAZOLE NITRATE',
#  'CLINDAMYCIN PALMITATE HYDROCHLORIDE',
#  'EPLERENONE',
#  'SALICYLIC ACID AND BENZOYL PEROXIDE',
#  'DINOPROSTONE',
#  'ACETAMINOPHEN DEXTROMETHORPHAN HYDROBROMIDE AND PHENYLEPHRINE HYDROCHLORIDE',
#  'ETHIONAMIDE',
#  'ZINC GLUCONATE VALERIAN AND CHAMOMILE',
#  'DEXTROSE SOYBEAN OIL ELECTROLYTES LYSINE PHENYLALANINE LEUCINE VALINE THREONINE METHIONINE ISOLEUCINE TRYPTOPHAN ALANINE ARGININE GLYCINE PROLINE HISTIDINE GLUTAMIC ACID SERINE ASPARTIC ACID AND TYROSINE',
#  'TOOTHPASTE',
#  'BUPRENORPHINE HCL',
#  'MEMANTINE HYDROCHLORIDE',
#  'CISPLATIN',
#  'ZIPRASIDONE MESYLATE',
#  'ANHYDROUS CITRIC ACID ASPIRIN AND SODIUM BICARBONATE',
#  'VERBENA OFFICINALIS',
#  'MINOXIDIL',
#  'PHENAZOPYRIDINE',
#  'PIPERACILLIN SODIUMTAZOBACTAM SODIUM',
#  ' VERATRUM ALB',
#  'MOXIFLOXACIN HYDROCHLORIDE',
#  'ANTIFUNGAL SPRAY POWDER',
#  'NESIRITIDE',
#  'CAPTORPIL',
#  'SEVELAMER CARBONATE',
#  'PETROLATUM',
#  'CEFACLOR',
#  'TOLTERODINE',
#  'LIDOCAINE HYDROCHLORIDE ANHYDROUS',
#  'FROVATRIPTAN',
#  'GLIMEPIRIDE',
#  'CASPOFUNGIN ACETATE',
#  'THIOGUANINE',
#  '-TOCOPHEROL ACETATE DL- THIAMINE MONONITRATE RIBOFLAVIN NIACINAMIDE PYRIDOXINE HYDROCHLORIDE FOLIC ACID CYANOCOBALAMIN CALCIUM CARBONATE IRON ZINC OXIDE AND CUPRIC OXIDE',
#  'CEFEPIME HYDROCHLORIDE',
#  'FLUOXETINE HYDROCHLORIDE',
#  'SODIUM FLUORIDE',
#  'DUTASTERIDE',
#  'ITRACONAZOLE CAPSULES',
#  'ETOMIDATE INJECTION',
#  'LITHIUM',
#  'DOXORUBICIN',
#  'OXACILLIN SODIUM',
#  'ASPIRIN 81 MG',
#  'XYLITOL',
#  'SODIUM FLUORIDE F-18',
#  'NEOMYCIN POLYMYXIN B PRAMOXINE HCL',
#  'PARICALCITOL',
#  'CITALOPRAM TABLET',
#  'CALCIUM ASCORBATE DIHYDRATE CHOLECALCIFEROL DL-A TOCOPHERYL ACETATE RIBOFLAVIN NIACINAMIDE FOLATE BIOTIN CALCIUM FERROUS ASPARTO GLYCINATE POTASSIUM IODIDE MAGNESIUM OXIDE ZINC BISGLYCINATE CHELATE ALPHA LINOLEIC ACID DHA EPA',
#  'INTERFERON ALFA-2A',
#  'SODIUM HYALURONATE',
#  'DACTINOMYCIN',
#  'DEXAMETHASONE SODIUM PHOSPHATE',
#  'BUPIVACAINE HYDROCHLORIDE AND EPINEPHRINE',
#  'SODIUM CITRATE',
#  'FLUTICASONE FUROATE',
#  'ESTRADIOL',
#  'LEVOBUNOLOL HYDROCHLORIDE',
#  'SIROLIMUS',
#  'EXENATIDE',
#  'GALANTAMINE',
#  'CODEINE PHOSPHATE',
#  ' LACHESIS  NAJA  NUX VOM',
#  'NICOITNE POLACRILEX',
#  'PERFLUTREN',
#  'PHENYLEPHRINE HYDROCHLORIDE',
#  'VANCOMYCIN',
#  'IBUPROFEN AND PSEUDOEPHEDRINE HYDROCHLORIDE',
#  'IODIXANOL',
#  'OLOPATADINE HYDROCHLORIDE',
#  'HYDROCORTISONE CONTINUOUS SPRAY',
#  'POTASSIUM PHOSPHATE MONOBASIC AND POTASSIUM PHOSPHATE DIBASIC',
#  'FENTANYL CITRATE',
#  'SPIRONOLACTONE',
#  'CYPROHEPTADINE',
#  '-TOCOPHEROL ACETATE DL- BIOTIN FOLIC ACID CYANOCOBALAMIN AND PHYTONADIONE',
#  ...]

# %%
# https://stats.stackexchange.com/questions/123060/clustering-a-long-list-of-strings-words-into-similarity-groups
char_lim = 25

words_og = generic_name_unique

# Cut off all but the first set of characters
if char_lim is not None:
    words = [w[:char_lim] for w in words_og]
else:
    words = words_og

# Get similarity matrix
words = np.asarray(words) 
lev_similarity = -1*np.array([[distance(w1,w2) for w1 in words] for w2 in words])

# Fit an affinity model
affprop = sklearn.cluster.AffinityPropagation(affinity="precomputed", damping=0.5)
affprop.fit(lev_similarity)

# Group the words with their respective clusters
cluster_list = []
gen_name_list = []
for cluster_id in np.unique(affprop.labels_):
    exemplar = words[affprop.cluster_centers_indices_[cluster_id]]
    cluster = np.unique(words[np.nonzero(affprop.labels_==cluster_id)])
    cluster_str = ", ".join(cluster)
    print(" - *%s:* %s" % (exemplar, cluster_str))
    for name in cluster:
        cluster_list.append(exemplar)
        gen_name_list.append(name)
# Out:
#  - *MAGNESIUM SULFATE:*  LACHESIS  NAJA  NUX VOM, MAGNESIUM CITRATE, MAGNESIUM HYDROXIDE, MAGNESIUM OXIDE, MAGNESIUM SALICYLATE, MAGNESIUM SULFATE, MAGNESIUM SULFATE HEPTAHY, MAGNESIUM SULFATE UNSPECI, SELENIUM SULFIDE
#  - *CHORIONIC GONADOTROPIN:* CHORIOGONADOTROPIN ALFA, CHORIONIC GONADOTROPIN, FIBRINOGEN HUMAN THROMBIN
#  - *AMLODIPINE BESYLATE AND V:* AMLODIPINE BESYLATE, AMLODIPINE BESYLATE AND A, AMLODIPINE BESYLATE AND B, AMLODIPINE BESYLATE AND O, AMLODIPINE BESYLATE AND V
#  - *PSEUDOEPHEDRINE HCL:* PHENYLEPHRINE HCL, PSEUDOEPHEDRINE, PSEUDOEPHEDRINE HCL, PSEUDOEPHEDRINE HYDROCHLO
#  - *ONE STEP WART REMOVER:* ONE STEP CLEAR WART REMOV, ONE STEP CORN REMOVER, ONE STEP WART REMOVER, ONE STEP WART REMOVER CLE, ONE STEP WART REMOVER STR, ONE-STEP CORN REMOVER CLE, ONE-STEP WART REMOVER TAN
#  - *BECLOMETHASONE DIPROPIONA:* BECLOMETHASONE DIPROPIONA, BETAMETHASONE DIPROPIONAT, DEXAMETHASONE SODIUM PHOS
#  - *CAFFEINE MAGNESIUM SALICY:* CAFFEINE MAGNESIUM SALICY, CHOLINE MAGNESIUM TRISALI
#  - *MENTHOL:*  FLUOR, ATENOLOL, BENADRYL, BREATHEZE, CEFPROZIL, DANAZOL, ETHANOL, FENTANYL, GINKGO, HAWTHORN, IOHEXOL, KENALOG, MANNITOL, MELPHALAN, MENTHOL, METHYLDOPA, MIGLITOL, PANTHENOL, PHENOL, RAMELTEON, RENAGEL, TENECTEPLASE, XYLITOL
#  - *ACONITUM NAPELLUS ARSENIC:* ACONITUM NAP AESCULUS HIP, ACONITUM NAPELLUS ARSENIC
#  - *RANITIDINE:* AMANTADINE, ANTIHISTAMINE, APRACLONIDINE, AZACITIDINE, AZACITIDINE FOR, AZATHIOPRINE, CARMUSTINE, CIMETIDINE, FAMOTIDINE, LAMIVUDINE, LAMOTRIGINE, NATEGLINIDE, NIZATIDINE, PALIPERIDONE, PRIMIDONE, RANITIDINE, RANOLAZINE, RASAGILINE, RASBURICASE, REPAGLINIDE, ROBITUSSIN DM, ROTIGOTINE, TRABECTEDIN, TRIFLURIDINE
#  - *DEFEROXAMINE MESYLATE:* BENZTROPINE MESYLATE, DEFEROXAMINE MESYLATE, DIHYDROERGOTAMINE MESYLAT, GEMIFLOXACIN MESYLATE, LISDEXAMFETAMINE DIMESYLA, NELFINAVIR MESYLATE, PAROXETINE MESYLATE
#  - *THALLOUS CHLORIDE TL-201:* THALLOUS CHLORIDE TL 201, THALLOUS CHLORIDE TL-201
#  - *BISOPROLOL FUMARATE:* BISOPROLOL FUMARATE, BISOPROLOL FUMARATE AND H, IBUTILIDE FUMARATE, KETOTIFEN FUMARATE, METOPROLOL SUCCINATE
#  - *DIPHENHYDRAMINE CITRATE I:* DIPHENHYDRAMINE CITRATE A, DIPHENHYDRAMINE CITRATE I, ORPHENADRINE CITRATE
#  - *TOLNAFTATE JOCK ITCH POWD:* MEDICATED JOCK ITCH POWDE, TOLNAFTATE ATHLETES FOOT , TOLNAFTATE JOCK ITCH POWD
#  - *ESTRADIOL CYPIONATE:* ESTRADIOL AND LEVONORGEST, ESTRADIOL AND NORETHINDRO, ESTRADIOL CYPIONATE, ESTRADIOL ESTRIOL FOLLICU, ESTRADIOL VALERATE, ESTRADIOL/NORGESTIMATE, ESTROGENS CONJUGATED, TESTOSTERONE CYPIONATE
#  - *RASAGILINE MESYLATE:* ATRACURIUM BESYLATE, BROMOCRIPTINE MESYLATE, CISATRACURIUM BESYLATE, DELAVIRDINE MESYLATE, DOLASETRON MESYLATE, DOXAZOSIN MESYLATE, EPROSARTAN MESYLATE, IMATINIB MESYLATE, RASAGILINE MESYLATE, ZIPRASIDONE MESYLATE
#  - *ALUMINUM HYDROXIDE AND MA:* ALUMINUM HYDROXIDE, ALUMINUM HYDROXIDE AND MA, ALUMINUM ZIRCONIUM TRICHL
#  - *SALSALATE:* AGALSIDASE BETA, ALTEPLASE, BACILLUS CALMETTE-GUERIN, FELBAMATE, GALSULFASE, IDURSULFASE, LACTULOSE, MANGANESE, ORLISTAT, PREDNICARBATE, RETEPLASE, SALSALATE, SARGRAMOSTIM, SAW PALMETTO, SENNA LEAF, SEVOFLURANE, SUCRALFATE, SULFASALAZINE, TOLNAFTATE, ZAFIRLUKAST
#  - *VITAMIN A ASCORBIC ACID C:* -CAROTENE ASCORBIC ACID C, VITAMIN A ASCORBIC ACID C, VITAMIN A VITAMIN C VITAM
#  - *HALOPERIDOL DECANOATE:* FLUPHENAZINE DECANOATE, HALOPERIDOL DECANOATE, HALOPERIDOL LACTATE, NANDROLONE DECANOATE, SALMETEROL XINAFOATE
#  - *PANTOPRAZOLE SODIUM:* ANTICOAGULANT SODIUM CITR, BALSALAZIDE DISODIUM, ESOMEPRAZOLE SODIUM, LANSOPRAZOLE AMOXICILLIN , LANSOPRAZOLE DELAYED RELE, PANTOOPRAZOLE SODIUM, PANTOPRAZOLE SODIUM, PENTOSAN POLYSULFATE SODI, RABEPRAZOLE SODIUM
#  - *OXYCODONE HYDROCHLORIDE:* AMIODARONE HYDROCHLORIDE, NALOXONE HYDROCHLORIDE, NEFAZODONE HYDROCHLORIDE, OXYCODONE AND ACETAMINOPH, OXYCODONE AND ASPIRIN, OXYCODONE HYDROCHLORIDE, OXYCODONE HYDROCHLORIDE A, OXYMETAZOLINE HYDROCHLORI, OXYMORPHONE HYDROCHLORIDE, PIOGLITAZONE HYDROCHLORID, TRAZODONE HYDROCHLORIDE
#  - *FOOT ODOR CONTROL SPRAY:* FOOT ODOR CONTROL POWDER , FOOT ODOR CONTROL SPRAY, FOOT ODOR CONTROL SPRAY P
#  - *ZINC GLUCONATE ROSA CANIN:* ZINC GLUCONATE EUPATORIUM, ZINC GLUCONATE MENTHA PIP, ZINC GLUCONATE ROSA CANIN, ZINC GLUCONATE SAMBUCUS N, ZINC GLUCONATE VALERIAN A
#  - *LOTEPREDNOL ETABONATE AND:* LOTEPREDNOL ETABONATE, LOTEPREDNOL ETABONATE AND
#  - *TRETINOIN:* ACETAMINOPHEN, BACITRACIN ZINC, ERYTHROPOIETIN, GRISEOFULVIN, IMATINIB, ISOTRETINOIN, NITROFURANTOIN, NOREPINEPHRINE, NORETHINDRONE, PHENYTOIN, PREDNISOLONE, PREGABALIN, QUERCETIN, QUETIAPINE, TERBINAFINE, TETROFOSMIN, TIROFIBAN, TOLTERODINE, TREPROSTINIL, TRETINOIN, TRICLOSAN, TRIPTORELIN, TUSSIN DM
#  - *SUMATRIPTAN SUCCINATE:* ALMOTRIPTAN MALATE, DESVENLAFAXINE SUCCINATE, FROVATRIPTAN SUCCINATE, RIZATRIPTAN BENZOATE, SUMATRIPTAN AND NAPROXEN , SUMATRIPTAN SUCCINATE, SUMATRIPTAN SUCCINATE AND
#  - *BOSENTAN:* AMBRISENTAN, APREPITANT, BERACTANT, BOSENTAN, BUSULFAN, CANDESARTAN, COAL TAR, COLLAGEN, DOCETAXEL, EXEMESTANE, FOSPHENYTOIN, GABAPENTIN, GREEN TEA, IRBESARTAN, IRON DEXTRAN, JOHNS WORT, MONTELUKAST, NABUMENTONE, TOLVAPTAN, VALSARTAN, VORINOSTAT, ZILEUTON
#  - *ISOSORBIDE MONONITRATE:* DEXTROSE MONOHYDRATE, ISOSORBIDE DINITRATE, ISOSORBIDE MONONITRATE, TESTOSTERONE ENANTHATE
#  - *CARBAMIDE PEROXIDE:* BENZOYL PEROXIDE, CARBAMIDE PEROXIDE, CARBAMIDE PEROXIDE 6, NIACINAMIDE ADENOSINE
#  - *INSULIN HUMAN:* ALBUMIN HUMAN, INSULIN ASPART, INSULIN DETEMIR, INSULIN GLARGINE, INSULIN GLULISINE, INSULIN HUMAN, INSULIN LISPRO, IRON SUPPLEMENT THERAPY, NYSTATIN CREAM, NYSTATIN OINTMENT, PSYLLIUM HUSK
#  - *NA:*  CALC, 1%, 4, 5%, 65%, ALPHA, BETA, ENEMA, GARLIC, HONEY, L-DOPA, MESNA, NA, RHUBARB, SENNA, ST, STARCH, TEA, WATER, ZINC
#  - *MYCOPHENOLATE MOFETIL:* -TOCOPHEROL ACETATE DL- T, CEFPODOXIME PROXETIL, MYCOPHENOLATE MOFETIL, MYCOPHENOLATE MOFETIL HYD
#  - *PENICILLIN G PROCAINE:* PENICILLIN G BENZATHINE, PENICILLIN G PROCAINE, PENICILLIN V POTASSIUM
#  - *CITALOPRAM TABLETS:* CARBIDOPA TABLETS, CITALOPRAM HYDROBROMIDE, CITALOPRAM TABLET, CITALOPRAM TABLETS, ESCITALOPRAM OXALATE, IBRITUMOMAB TIUXETAN, METHOCARBAMOL TABLETS
#  - *PYRETHRUM EXTRACT AND PIP:* LIVER EXTRACT HGH SOMATOT, PYRETHRUM EXTRACT AND PIP
#  - *FENTANYL TRANSDERMAL SYST:* ESTRADIOL TRANSDERMAL SYS, FENTANYL TRANSDERMAL SYST
#  - *5 MG:*  MET, 0XYGEN, 25 MCG, 5 MCG, 5 MG, 50%, 6 MG, 6 MG AND 50 MG, ARG, GOLD, IRON, OXYGEN
#  - *BETHANECHOL CHLORIDE 50 M:* BETHANECHOL CHLORIDE, BETHANECHOL CHLORIDE 10 M, BETHANECHOL CHLORIDE 25 M, BETHANECHOL CHLORIDE 5 MG, BETHANECHOL CHLORIDE 50 M
#  - *OMEPRAZOLE MAGNESIUM:* ARIPIPRAZOLE ORALLY DISIN, ESOMEPRAZOLE MAGNESIUM, MILK OF MAGNESIA, OMEPRAZOLE AND SODIUM BIC, OMEPRAZOLE MAGNESIUM
#  - *METHYLPHENIDATE HYDROCHLO:* (METHYLPHENIDATE HYDROCHL, DEXMETHYLPHENIDATE HYDROC, METHAMPHETAMINE HYDROCHLO, METHYLPHENIDATE HYDROCHLO, METOCLOPRAMIDE HYDROCHLOR, TRIHEXYPHENIDYL HYDROCHLO
#  - *POLYETHYLENE GLYCOL 3350:* METHOXY POLYETHYLENE GLYC, POLYETHYLENE GLYCOL, POLYETHYLENE GLYCOL (3350, POLYETHYLENE GLYCOL 3350, POLYETHYLENE GLYCOL 3350 , POLYETHYLENE GLYCOL 400, POLYETHYLENE GLYCOL 400 A, POLYETHYLENE GLYCOL AND P
#  - *ECHINACEA ANGUSTIFOLIA HA:* ECHINACEA ANGUSTIFOLIA HA
#  - *WART REMOVER LIQUID:* WART REMOVER GEL PEN, WART REMOVER GEL TUBE, WART REMOVER LIQUID, WART REMOVER LIQUID FOOT , WART REMOVER MEDICATED DI
#  - *NORETHINDRONE AND ETHINYL:* DROSPIRENONE AND ETHINYL , NORELGESTROMIN AND ETHINY, NORETHINDRONE AND ETHINYL, SIMETHICONE AND CALCIUM C
#  - *ATROPA BELLADONNA:* AGRIMONIA EUPATORIA, ATROPA BELLADONNA, ATROPA BELLADONNA ROOT, CARBIDOPA AND LEVODOPA
#  - *L-CARNITINE L-GLUTAMINE L:* L-CARNITINE L-GLUTAMINE L
#  - *AZITHROMYCIN DIHYDRATE:* AMPHOTERICIN B DIMYRISTOY, AZITHROMYCIN DIHYDRATE, AZITHROMYCIN MONOHYDRATE, CEFTIBUTEN DIHYDRATE, CLARITHROMYCIN EXTENDED-R, ERYTHROMYCIN ETHYLSUCCINA, ERYTHROMYCIN STEARATE
#  - *CITALOPRAM:* AQUAFLORA, BIMATOPROST, CICLOPIROX, CITALOPRAM, DIGITALIS PURPUREA, DISULFIRAM, ESCITALOPRAM, ESCITSLOPRAM, LATANOPROST, LISINOPRIL, MIGLUSTAT, NASAL SPRAY
#  - *ATHLETES FOOT SPRAY:* ATHLETE S FOOT SPRAY, ATHLETES FOOT ANTIFUNGAL , ATHLETES FOOT LIQUID, ATHLETES FOOT POWDER SPRA, ATHLETES FOOT SPRAY, REGULAR STRENGTH ASPIRIN
#  - *DEXAMETHASONE:* BETAMETHASONE, DESOXIMETASONE, DEXAMETHASONE, DEXAMETHASONE 1, DEXTROAMPHETAMINE, DEXTROMETHORPHAN, DIMETHICONE, OXYMETHOLONE, TETRAKIS(2-METHOXYISOBUTY
#  - *APIS MELLIFICA APISINUM A:* APIS MELLIFICA APISINUM A, APIS MELLIFICA BERBERIS V
#  - *NELARABINE:* ASPARAGINASE, BUPIVACAINE, CLADRIBINE, CLOFARABINE, CYTARABINE, DACARBAZINE, DECITABINE, DEFLAZACORT, DESIPRAMINE, DESLORATADINE, EDARAVONE, EMTRICITABINE, GALANTAMINE, GEMCITABINE, MESALAMINE, METAXALONE, MIRTAZAPINE, NELARABINE, NESIRITIDE, NEVIRAPINE, SERTRALINE, SILVER SULFADIAZINE, SULFADIAZINE, TETRABENAZINE, TETRACAINE, TIAGABINE, VENLAFAXINE, VINORELBINE
#  - *CALCITRIOL:*  KALI IOD , ALBUTEROL, CALCIFEDIOL, CALCIPOTRIENE, CALCITONIN SALMON, CALCITRIOL, CALCITRIOL CAPSULES 0, CAPECITABINE, CEFDITOREN PIVOXIL, CHOLECALCIFEROL, CHOLESTEROL, COD LIVER OIL, DOXERCALCIFEROL, ERGOCALCIFEROL, LABETALOL, PARICALCITOL, RAMIPRIL
#  - *EXTRA THICK CALLUS REMOVE:* EXTRA THICK CALLUS REMOVE
#  - *CHLOROTHIAZIDE:* CHLORAL HYDRATE, CHLOROTHIAZIDE, CHLOROTHIAZIDE SODIUM, CHLORPROMAZINE, CHLORPROPAMIDE, CHLORTHALIDONE, CHLORZOXAZONE, CICLOPIROX OLAMINE, HYDROCHLOROTHIAZIDE, HYDROCHLOROTHIAZIDE AND T
#  - *STANDARDIZED SENNA CONCEN:* STANDARDIZED SENNA CONCEN
#  - *LOSARTAN POTASSIUM AND HY:* LOSARTAN POTASSIUM, LOSARTAN POTASSIUM AND HY, RIFAMPIN ISONIAZID AND PY
#  - *MICONAZORB ANTIFUNGAL POW:* MICONAZORB AF ANTIFUNGAL , MICONAZORB ANTIFUNGAL POW
#  - *EPOETIN ALFA:* DARBEPOETIN ALFA, DORNASE ALFA, EPOETIN ALFA, FLUOXETINE CAPSULES, FOLLITROPIN ALFA, PORACTANT ALFA, THYROTROPIN ALFA, VERBENA OFFICINALIS
#  - *ALISKIREN HEMIFUMARATE AN:* ALISKIREN HEMIFUMARATE, ALISKIREN HEMIFUMARATE AN, EFAVIRENZ EMTRICITABINE A
#  - *SODIUM FLUORIDE F 18:* SODIUM FLUORIDE AND POTAS, SODIUM FLUORIDE AND TRICL, SODIUM FLUORIDE F 18, SODIUM FLUORIDE F-18, SODIUM FLUORIDE F18, SODIUM IODIDE I 123, SODIUM IODIDE I 131, SODIUM POLYSTYRENE SULFON
#  - *ABACAVIR SULFATE:*  RATANHIA VIPERA BERUS AE, ABACAVIR SULFATE, ABACAVIR SULFATE AND LAMI, ABACAVIR SULFATE LAMIVUDI, ALBUTEROL SULFATE, AMIKACIN SULFATE, ATAZANAVIR SULFATE, INDINAVIR SULFATE, SAQUINAVIR MESYLATE
#  - *SUMATRIPTAN:* 5-HYDROXYTRYPTOPHAN, FROVATRIPTAN, NARATRIPTAN, SITAGLIPTIN, SOMATROPIN, SUMATRIPTAN, ZOLMITRIPTAN
#  - *VITAMIN:* ACITRETIN, BACITRACIN, BORTEZOMIB, CINNAMON, CISPLATIN, CROTAMITON, DIGITALIS, LECITHIN, NIACIN, NYSTATIN, PEGVISOMANT, QUINAPRIL, RETAPAMULIN, RIBAVIRIN, RIFABUTIN, RIFAMPIN, RIFAXIMIN, RITUXIMAB, VALERIAN, VANDETANIB, VIGABATRIN, VITAMIN, VITAMIN A, VITAMIN B COMPLEX, VITAMIN E, WARFARIN
#  - *INFLUENZINUM (2016-2017):* INFLUENZINUM (2016-2017), INFLUENZINUM (2017-2018)

# %%
gen_name_list
# Out:
# [' LACHESIS  NAJA  NUX VOM',
#  'MAGNESIUM CITRATE',
#  'MAGNESIUM HYDROXIDE',
#  'MAGNESIUM OXIDE',
#  'MAGNESIUM SALICYLATE',
#  'MAGNESIUM SULFATE',
#  'MAGNESIUM SULFATE HEPTAHY',
#  'MAGNESIUM SULFATE UNSPECI',
#  'SELENIUM SULFIDE',
#  'CHORIOGONADOTROPIN ALFA',
#  'CHORIONIC GONADOTROPIN',
#  'FIBRINOGEN HUMAN THROMBIN',
#  'AMLODIPINE BESYLATE',
#  'AMLODIPINE BESYLATE AND A',
#  'AMLODIPINE BESYLATE AND B',
#  'AMLODIPINE BESYLATE AND O',
#  'AMLODIPINE BESYLATE AND V',
#  'PHENYLEPHRINE HCL',
#  'PSEUDOEPHEDRINE',
#  'PSEUDOEPHEDRINE HCL',
#  'PSEUDOEPHEDRINE HYDROCHLO',
#  'ONE STEP CLEAR WART REMOV',
#  'ONE STEP CORN REMOVER',
#  'ONE STEP WART REMOVER',
#  'ONE STEP WART REMOVER CLE',
#  'ONE STEP WART REMOVER STR',
#  'ONE-STEP CORN REMOVER CLE',
#  'ONE-STEP WART REMOVER TAN',
#  'BECLOMETHASONE DIPROPIONA',
#  'BETAMETHASONE DIPROPIONAT',
#  'DEXAMETHASONE SODIUM PHOS',
#  'CAFFEINE MAGNESIUM SALICY',
#  'CHOLINE MAGNESIUM TRISALI',
#  ' FLUOR',
#  'ATENOLOL',
#  'BENADRYL',
#  'BREATHEZE',
#  'CEFPROZIL',
#  'DANAZOL',
#  'ETHANOL',
#  'FENTANYL',
#  'GINKGO',
#  'HAWTHORN',
#  'IOHEXOL',
#  'KENALOG',
#  'MANNITOL',
#  'MELPHALAN',
#  'MENTHOL',
#  'METHYLDOPA',
#  'MIGLITOL',
#  'PANTHENOL',
#  'PHENOL',
#  'RAMELTEON',
#  'RENAGEL',
#  'TENECTEPLASE',
#  'XYLITOL',
#  'ACONITUM NAP AESCULUS HIP',
#  'ACONITUM NAPELLUS ARSENIC',
#  'DANTROLENE SODIUM',
#  'DIVALPROEX SODIUM',
#  'EPOPROSTENOL SODIUM',
#  'FENOPROFEN CALCIUM',
#  'FLUORESCEIN SODIUM',
#  'FLURBIPROFEN SODIUM',
#  'FOSINOPIRL SODIUM',
#  'IBUPROFEN 200 MG',
#  'IBUPROFEN 200MG',
#  'IBUPROFEN AND DIPHENHYDRA',
#  'IBUPROFEN LYSINE',
#  'IBUPROFEN PSEUDOEPHEDRINE',
#  'IBUPROFEN SODIUM',
#  'MUPIROCIN CALCIUM',
#  'NAPROXEN SODIUM',
#  'PEMETREXED DISODIUM',
#  'OLMESARTAN MEDOXOMIL',
#  'OLMESARTAN MEDOXOMIL-HYDR',
#  'TELMISARTAN/AMLODIPINE',
#  'FLECAINIDE ACETATE',
#  'FLECAINIDE ACETATE TABLET',
#  'GLATIRAMER ACETATE',
#  'LANREOTIDE ACETATE',
#  'LEUPROLIDE ACETATE',
#  'OCTREOTIDE ACETATE',
#  'VITAMIN A ACETATE ',
#  'AMOXICILLIN',
#  'AMPICILLIN',
#  'BIVALIRUDIN',
#  'DANDELION',
#  'DOXAZOSIN',
#  'DOXYCYCLINE',
#  'OXACILLIN',
#  'OXALIPLATIN',
#  'OXANDROLONE',
#  'OXAPROZIN',
#  'PENICILLIN G',
#  'PENTOXIFYLLINE',
#  'PORK COLLAGEN',
#  'HYDROXYZINE PAMOATE',
#  'IMIPRAMINE PAMOATE',
#  'MILRINONE LACTATE',
#  'OLANZAPINE PAMOATE',
#  'PALIPERIDONE PALMITATE',
#  'PYRANTEL PAMOATE',
#  'TRIMIPRAMINE MALEATE',
#  'TRIPTORELIN PAMOATE',
#  'ARSENIC TRIOXIDE',
#  'CICLESONIDE',
#  'DIAZOXIDE',
#  'GINKGO BILOBA',
#  'LINEZOLID',
#  'MILK THISTLE',
#  'MINOXIDIL',
#  'NITRIC OXIDE',
#  'NITROUS OXIDE',
#  'NITROUX OXIDE',
#  'ZICONOTIDE',
#  'ZINC CHLORIDE',
#  'ZINC GLUCONATE',
#  'ZINC OXIDE',
#  'ZINC OXIDE OINTMENT',
#  'ZINC SULFATE',
#  'AMOXICILLIN AND CLAVULANA',
#  'ASCORBIC ACID RETINOL ERG',
#  'ASPIRIN AND CAFFEINE',
#  'ASPIRIN AND DIPYRIDAMOLE',
#  'ASPIRIN ANHYDROUS CITRIC ',
#  'ASPIRIN CHLORPHENIRAMINE ',
#  'ASPIRINCAFFEINE',
#  'ASPRIN AND CAFFEINE',
#  'BACITRACIN ZINC NEOMYCIN ',
#  'IMIPENEM AND CILASTATIN S',
#  'LAMOTRIGINE CHEWABLE DISP',
#  'QUINUPRISTIN AND DALFOPRI',
#  'SULFUR AND RESORCINOL',
#  'IPRATROPIUM BROMIDE',
#  'IPRATROPIUM BROMIDE AND A',
#  'METHYLNALTREXONE BROMIDE',
#  'PANCURONIUM BROMIDE',
#  'PERINDOPRIL ERBUMINE',
#  'POTASSIUM BROMIDE',
#  'PROPANTHELINE BROMIDE',
#  'PYRIDOSTIGMINE BROMIDE',
#  'ROCURONIUM BROMIDE',
#  'TIOTROPIUM BROMIDE',
#  'VECURONIUM BROMIDE',
#  'HELIANTHEMUM NUMMULARIUM ',
#  'ORNITHOGALUM UMBELLATUM',
#  'ORNITHOGALUM UMBELLATUM H',
#  'AMANTADINE',
#  'ANTIHISTAMINE',
#  'APRACLONIDINE',
#  'AZACITIDINE',
#  'AZACITIDINE FOR',
#  'AZATHIOPRINE',
#  'CARMUSTINE',
#  'CIMETIDINE',
#  'FAMOTIDINE',
#  'LAMIVUDINE',
#  'LAMOTRIGINE',
#  'NATEGLINIDE',
#  'NIZATIDINE',
#  'PALIPERIDONE',
#  'PRIMIDONE',
#  'RANITIDINE',
#  'RANOLAZINE',
#  'RASAGILINE',
#  'RASBURICASE',
#  'REPAGLINIDE',
#  'ROBITUSSIN DM',
#  'ROTIGOTINE',
#  'TRABECTEDIN',
#  'TRIFLURIDINE',
#  'BENZTROPINE MESYLATE',
#  'DEFEROXAMINE MESYLATE',
#  'DIHYDROERGOTAMINE MESYLAT',
#  'GEMIFLOXACIN MESYLATE',
#  'LISDEXAMFETAMINE DIMESYLA',
#  'NELFINAVIR MESYLATE',
#  'PAROXETINE MESYLATE',
#  'THALLOUS CHLORIDE TL 201',
#  'THALLOUS CHLORIDE TL-201',
#  'BISOPROLOL FUMARATE',
#  'BISOPROLOL FUMARATE AND H',
#  'IBUTILIDE FUMARATE',
#  'KETOTIFEN FUMARATE',
#  'METOPROLOL SUCCINATE',
#  'DIPHENHYDRAMINE CITRATE A',
#  'DIPHENHYDRAMINE CITRATE I',
#  'ORPHENADRINE CITRATE',
#  'MEDICATED JOCK ITCH POWDE',
#  'TOLNAFTATE ATHLETES FOOT ',
#  'TOLNAFTATE JOCK ITCH POWD',
#  'ESTRADIOL AND LEVONORGEST',
#  'ESTRADIOL AND NORETHINDRO',
#  'ESTRADIOL CYPIONATE',
#  'ESTRADIOL ESTRIOL FOLLICU',
#  'ESTRADIOL VALERATE',
#  'ESTRADIOL/NORGESTIMATE',
#  'ESTROGENS CONJUGATED',
#  'TESTOSTERONE CYPIONATE',
#  'ATRACURIUM BESYLATE',
#  'BROMOCRIPTINE MESYLATE',
#  'CISATRACURIUM BESYLATE',
#  'DELAVIRDINE MESYLATE',
#  'DOLASETRON MESYLATE',
#  'DOXAZOSIN MESYLATE',
#  'EPROSARTAN MESYLATE',
#  'IMATINIB MESYLATE',
#  'RASAGILINE MESYLATE',
#  'ZIPRASIDONE MESYLATE',
#  'ALUMINUM HYDROXIDE',
#  'ALUMINUM HYDROXIDE AND MA',
#  'ALUMINUM ZIRCONIUM TRICHL',
#  'AGALSIDASE BETA',
#  'ALTEPLASE',
#  'BACILLUS CALMETTE-GUERIN',
#  'FELBAMATE',
#  'GALSULFASE',
#  'IDURSULFASE',
#  'LACTULOSE',
#  'MANGANESE',
#  'ORLISTAT',
#  'PREDNICARBATE',
#  'RETEPLASE',
#  'SALSALATE',
#  'SARGRAMOSTIM',
#  'SAW PALMETTO',
#  'SENNA LEAF',
#  'SEVOFLURANE',
#  'SUCRALFATE',
#  'SULFASALAZINE',
#  'TOLNAFTATE',
#  'ZAFIRLUKAST',
#  '-CAROTENE ASCORBIC ACID C',
#  'VITAMIN A ASCORBIC ACID C',
#  'VITAMIN A VITAMIN C VITAM',
#  'FLUPHENAZINE DECANOATE',
#  'HALOPERIDOL DECANOATE',
#  'HALOPERIDOL LACTATE',
#  'NANDROLONE DECANOATE',
#  'SALMETEROL XINAFOATE',
#  'CARVEDILOL PHOSPHATE',
#  'CHLOROQUINE PHOSPHATE',
#  'CHROMIUM PICOLINATE',
#  'CODEINE PHOSPHATE',
#  'DIBASIC SODIUM PHOSPHATE ',
#  'DISOPYRAMIDE PHOSPHATE',
#  'INDIUM IN -111 PENTETREOT',
#  'SODIUM MONOFLUOROPHOSPHAT',
#  'SODIUM PHENYLACETATE AND ',
#  'SODIUM PHOSPHATE',
#  'SODIUM THIOSULFATE',
#  'AMPHETAMINE SULFATE',
#  'ATROPINE SULFATE',
#  'BEPOTASTINE BESILATE',
#  'BLEOMYCIN SULFATE',
#  'CODEINE SULFATE',
#  'FLUVOXAMINE MALEATE',
#  'GENTAMICIN SULFATE',
#  'HYOSCYAMINE SULFATE',
#  'HYOSCYAMINE SULFATE METHE',
#  'LOXAPINE SUCCINATE',
#  'METAPROTERENOL SULFATE',
#  'MORPHINE SULFATE',
#  'NEOMYCIN SULFATE',
#  'NEOSTIGMINE METHYLSULFATE',
#  'PENTAMIDINE ISETHIONATE',
#  'PHENELZINE SULFATE',
#  'POLYMYXIN B SULFATE',
#  'PROTAMINE SULFATE',
#  'QUINIDINE SULFATE',
#  'QUININE SULFATE',
#  'TERBUTALINE SULFATE',
#  'TOBRAMYCIN SULFATE',
#  'TRANYLCYPROMINE SULFATE',
#  'VINBLASTINE SULFATE',
#  'VINCRISTINE SULFATE',
#  'DEXTROMEHTORPHAN HBR / GU',
#  'DEXTROMETHORPHAN HBR AND ',
#  'DEXTROMETHORPHAN HBR DOXY',
#  'DEXTROMETHORPHAN HBR GUAI',
#  'DEXTROSE SOYBEAN OIL ELEC',
#  'ESTROGENS ESTERIFIED AND ',
#  'ACETAMINOPHEN ASPIRIN (NS',
#  'ACETAMINOPHEN ASPIRIN AND',
#  'ACETAMINOPHEN ASPIRIN CAF',
#  'ACETAMINOPHEN ASPIRIN SAL',
#  'ACETAMINOPHEN ASPRIN CAFF',
#  'ACETAMINOPHEN GUAIFENESIN',
#  'AZATHIOPRINE SODIUM',
#  'LEVOTHYROXINE SODIUM',
#  'LEVOTHYROXINE SODIUM ANHY',
#  'LIOTHYRONINE SODIUM',
#  'LIOTHYRONINE SODIUM LEVOT',
#  'BUTALBITAL ACETAMINOPHEN ',
#  'BUTALBITAL ASPIRIN AND CA',
#  'CAFFEINE',
#  'CEFACLOR',
#  'CEFDINIR',
#  'CEFEPIME',
#  'CEFIXIME',
#  'CEFOTAXIME',
#  'CEFOXITIN',
#  'CEFTAZIDIME',
#  'CEFTRIAXONE',
#  'CEFUROXIME',
#  'CEFUROXIME AXETIL',
#  'CETIRIZINE',
#  'CETUXIMAB',
#  'CEVIMELINE',
#  'COLCHICINE',
#  'EFAVIRENZ',
#  'ENFUVIRTIDE',
#  'INFLIXIMAB',
#  'PEGFILGRASTIM',
#  'PERFLUTREN',
#  'SUCCIMER',
#  ' BARYTA CARB',
#  ' URTICA UR',
#  'ABACAVIR',
#  'ABATACEPT',
#  'ANALGESIC',
#  'ATAZANAVIR',
#  'CIDOFOVIR',
#  'DARUNAVIR',
#  'ENTECAVIR',
#  'MARAVIROC',
#  'RALTEGRAVIR',
#  'RITONAVIR',
#  'TADALAFIL',
#  'TIPRANAVIR',
#  'ZANAMIVIR',
#  'DEXTROMETHORPHAN HYDROBRO',
#  'CLOBETASOL PROPIONATE',
#  'FLUTICASONE FUROATE',
#  'FLUTICASONE PROPIONATE',
#  'FLUTICASONE PROPIONATE AN',
#  'ANTICOAGULANT SODIUM CITR',
#  'BALSALAZIDE DISODIUM',
#  'ESOMEPRAZOLE SODIUM',
#  'LANSOPRAZOLE AMOXICILLIN ',
#  'LANSOPRAZOLE DELAYED RELE',
#  'PANTOOPRAZOLE SODIUM',
#  'PANTOPRAZOLE SODIUM',
#  'PENTOSAN POLYSULFATE SODI',
#  'RABEPRAZOLE SODIUM',
#  'AMIODARONE HYDROCHLORIDE',
#  'NALOXONE HYDROCHLORIDE',
#  'NEFAZODONE HYDROCHLORIDE',
#  'OXYCODONE AND ACETAMINOPH',
#  'OXYCODONE AND ASPIRIN',
#  'OXYCODONE HYDROCHLORIDE',
#  'OXYCODONE HYDROCHLORIDE A',
#  'OXYMETAZOLINE HYDROCHLORI',
#  'OXYMORPHONE HYDROCHLORIDE',
#  'PIOGLITAZONE HYDROCHLORID',
#  'TRAZODONE HYDROCHLORIDE',
#  'FOOT ODOR CONTROL POWDER ',
#  'FOOT ODOR CONTROL SPRAY',
#  'FOOT ODOR CONTROL SPRAY P',
#  'ZINC GLUCONATE EUPATORIUM',
#  'ZINC GLUCONATE MENTHA PIP',
#  'ZINC GLUCONATE ROSA CANIN',
#  'ZINC GLUCONATE SAMBUCUS N',
#  'ZINC GLUCONATE VALERIAN A',
#  'LOTEPREDNOL ETABONATE',
#  'LOTEPREDNOL ETABONATE AND',
#  'ACETAMINOPHEN',
#  'BACITRACIN ZINC',
#  'ERYTHROPOIETIN',
#  'GRISEOFULVIN',
#  'IMATINIB',
#  'ISOTRETINOIN',
#  'NITROFURANTOIN',
#  'NOREPINEPHRINE',
#  'NORETHINDRONE',
#  'PHENYTOIN',
#  'PREDNISOLONE',
#  'PREGABALIN',
#  'QUERCETIN',
#  'QUETIAPINE',
#  'TERBINAFINE',
#  'TETROFOSMIN',
#  'TIROFIBAN',
#  'TOLTERODINE',
#  'TREPROSTINIL',
#  'TRETINOIN',
#  'TRICLOSAN',
#  'TRIPTORELIN',
#  'TUSSIN DM',
#  'ALMOTRIPTAN MALATE',
#  'DESVENLAFAXINE SUCCINATE',
#  'FROVATRIPTAN SUCCINATE',
#  'RIZATRIPTAN BENZOATE',
#  'SUMATRIPTAN AND NAPROXEN ',
#  'SUMATRIPTAN SUCCINATE',
#  'SUMATRIPTAN SUCCINATE AND',
#  'AMBRISENTAN',
#  'APREPITANT',
#  'BERACTANT',
#  'BOSENTAN',
#  'BUSULFAN',
#  'CANDESARTAN',
#  'COAL TAR',
#  'COLLAGEN',
#  'DOCETAXEL',
#  'EXEMESTANE',
#  'FOSPHENYTOIN',
#  'GABAPENTIN',
#  'GREEN TEA',
#  'IRBESARTAN',
#  'IRON DEXTRAN',
#  'JOHNS WORT',
#  'MONTELUKAST',
#  'NABUMENTONE',
#  'TOLVAPTAN',
#  'VALSARTAN',
#  'VORINOSTAT',
#  'ZILEUTON',
#  'DEXTROSE MONOHYDRATE',
#  'ISOSORBIDE DINITRATE',
#  'ISOSORBIDE MONONITRATE',
#  'TESTOSTERONE ENANTHATE',
#  'BENZOYL PEROXIDE',
#  'CARBAMIDE PEROXIDE',
#  'CARBAMIDE PEROXIDE 6',
#  'NIACINAMIDE ADENOSINE',
#  'ANTI-FUNGAL MICONAZOLE AT',
#  'ANTIFUNGAL CONTINUOUS LIQ',
#  'ANTIFUNGAL MICONAZOLE LIQ',
#  'ANTIFUNGAL MICONAZOLE POW',
#  'ANTIFUNGAL SPRAY LIQUID',
#  'ANTIFUNGAL TOLNAFTATELIQU',
#  'ACETAZOLAMIDE',
#  'BRINZOLAMIDE',
#  'DIMETHYL SULFOXIDE',
#  'EGG PHOSPHOLIPIDS',
#  'ETHIONAMIDE',
#  'ETHOSUXIMIDE',
#  'GEMTUZUMAB OZOGAMICIN',
#  'MENTHA PIPERITA',
#  'METHAZOLAMIDE',
#  'METHOCARBAMOL',
#  'METHYLPHENIDATE',
#  'METOCLOPRAMIDE',
#  'PENICILLAMINE',
#  'PYRAZINAMIDE',
#  'TEMOZOLOMIDE',
#  'THALIDOMIDE',
#  'CLOTRIMAZOLE AND BETAMETH',
#  'DROSPIRENONE AND ESTRADIO',
#  'EMTRICITABINE AND TENOFOV',
#  'GLYBURIDE AND METFORMIN H',
#  'PIOGLITAZONE AND GLIMEPIR',
#  'PIOGLITAZONE AND METFORMI',
#  'SITAGLIPTIN AND METFORMIN',
#  'IRBESARTAN AND HYDROCHLOR',
#  'SPIRONOLACTONE AND HYDROC',
#  'TELMISARTAN AND HYDROCHLO',
#  'TRIAMTERENE AND HYDROCHLO',
#  'VALSARTAN AND HYDROCHLORO',
#  'CEVIMELINE HYDROCHLORIDE',
#  'ELETRIPTAN HYDROBROMIDE',
#  'GEMCITABINE HYDROCHLORIDE',
#  'HYDRALAZINE HYDROCHLORIDE',
#  'MEFLOQUINE HYDROCHLORIDE',
#  'MEMANTINE HYDROCHLORIDE',
#  'METHADONE HYDROCHLORIDE',
#  'PROPARACAINE HYDROCHLORID',
#  'SERTRALINE HYDROCHLORIDE',
#  'TERBINAFINE HYDROCHLORIDE',
#  'TETRACAINE HYDROCHLORIDE',
#  'TETRACYCLINE HYDROCHLORID',
#  'TETRADECYL HYDROGEN SULFA',
#  'TRAMADOL HYDROCHLORIDE',
#  'TRAMADOL HYDROCHLORIDE AN',
#  'VENLAFAXINE HYDROCHLORIDE',
#  'CALCIPOTRIENE AND BETAMET',
#  'GUAIFENESIN AND DEXTROMET',
#  'GUAIFENESIN AND PSEUDOEPH',
#  'GUAIFENESIN DEXTROMETHORP',
#  '-TOCOPHEROL ACETATE DL- T',
#  'BETAMETHASONE ACETATE AND',
#  'ETHYNODIOL DIACETATE AND ',
#  'NORETHINDRONE ACETATE',
#  'NORETHINDRONE ACETATE AND',
#  'NORETHINDRONE ACETATE/ETH',
#  'BUPIVACAINE HYDROCHLORIDE',
#  'EPINASTINE HYDROCHLORIDE',
#  'GUANFACINE HYDROCHLORIDE',
#  'MEPIVACAINE HYDROCHLORIDE',
#  'ROPIVACAINE HYDROCHLORIDE',
#  'NICOITNE POLACRILEX',
#  'NICOTINE POLACRILEX',
#  'NICOTINE POLARILEX',
#  'ANHYDROUS CITRIC ACID ASP',
#  'CLOCORTOLONE PIVALATE',
#  'CORTISONE ACETATE',
#  'FLUDROCORTISONE ACETATE',
#  'HYDROCORTISONE ACETATE',
#  'HYDROCORTISONE ACETATE AN',
#  'HYDROCORTISONE AND ACETIC',
#  'HYDROCORTISONE BUTYRATE',
#  'HYDROCORTISONE CONTINUOUS',
#  'HYDROCORTISONE CREAM',
#  'HYDROCORTISONE SODIUM SUC',
#  'HYDROXYCHLOROQUINE SULFAT',
#  'MEDROXYPROGESTERONE ACETA',
#  'ALBUMIN HUMAN',
#  'INSULIN ASPART',
#  'INSULIN DETEMIR',
#  'INSULIN GLARGINE',
#  'INSULIN GLULISINE',
#  'INSULIN HUMAN',
#  'INSULIN LISPRO',
#  'IRON SUPPLEMENT THERAPY',
#  'NYSTATIN CREAM',
#  'NYSTATIN OINTMENT',
#  'PSYLLIUM HUSK',
#  ' CALC',
#  '1%',
#  '4',
#  '5%',
#  '65%',
#  'ALPHA',
#  'BETA',
#  'ENEMA',
#  'GARLIC',
#  'HONEY',
#  'L-DOPA',
#  'MESNA',
#  'NA',
#  'RHUBARB',
#  'SENNA',
#  'ST',
#  'STARCH',
#  'TEA',
#  'WATER',
#  'ZINC',
#  '-TOCOPHEROL ACETATE DL- T',
#  'CEFPODOXIME PROXETIL',
#  'MYCOPHENOLATE MOFETIL',
#  'MYCOPHENOLATE MOFETIL HYD',
#  'PENICILLIN G BENZATHINE',
#  'PENICILLIN G PROCAINE',
#  'PENICILLIN V POTASSIUM',
#  'CARBIDOPA TABLETS',
#  'CITALOPRAM HYDROBROMIDE',
#  'CITALOPRAM TABLET',
#  'CITALOPRAM TABLETS',
#  'ESCITALOPRAM OXALATE',
#  'IBRITUMOMAB TIUXETAN',
#  'METHOCARBAMOL TABLETS',
#  'LIVER EXTRACT HGH SOMATOT',
#  'PYRETHRUM EXTRACT AND PIP',
#  'ESTRADIOL TRANSDERMAL SYS',
#  'FENTANYL TRANSDERMAL SYST',
#  ' MET',
#  '0XYGEN',
#  '25 MCG',
#  '5 MCG',
#  '5 MG',
#  '50%',
#  '6 MG',
#  '6 MG AND 50 MG',
#  'ARG',
#  'GOLD',
#  'IRON',
#  'OXYGEN',
#  'BETHANECHOL CHLORIDE',
#  'BETHANECHOL CHLORIDE 10 M',
#  'BETHANECHOL CHLORIDE 25 M',
#  'BETHANECHOL CHLORIDE 5 MG',
#  'BETHANECHOL CHLORIDE 50 M',
#  'ARIPIPRAZOLE ORALLY DISIN',
#  'ESOMEPRAZOLE MAGNESIUM',
#  'MILK OF MAGNESIA',
#  'OMEPRAZOLE AND SODIUM BIC',
#  'OMEPRAZOLE MAGNESIUM',
#  '(METHYLPHENIDATE HYDROCHL',
#  'DEXMETHYLPHENIDATE HYDROC',
#  'METHAMPHETAMINE HYDROCHLO',
#  'METHYLPHENIDATE HYDROCHLO',
#  'METOCLOPRAMIDE HYDROCHLOR',
#  'TRIHEXYPHENIDYL HYDROCHLO',
#  'METHOXY POLYETHYLENE GLYC',
#  'POLYETHYLENE GLYCOL',
#  'POLYETHYLENE GLYCOL (3350',
#  'POLYETHYLENE GLYCOL 3350',
#  'POLYETHYLENE GLYCOL 3350 ',
#  'POLYETHYLENE GLYCOL 400',
#  'POLYETHYLENE GLYCOL 400 A',
#  'POLYETHYLENE GLYCOL AND P',
#  'ARTICAINE HYDROCHLORIDE A',
#  'CINACALCET HYDROCHLORIDE',
#  'CLINDAMYCIN HYDROCHLORIDE',
#  'DILTIAZEM HYDROCHLORIDE E',
#  'FLAVOXATE HYDROCHLORIDE',
#  'IRINOTECAN HYDROCHLORIDE',
#  'LIDOCAINE AND PRILOCAINE',
#  'LIDOCAINE HYDROCHLORIDE',
#  'LIDOCAINE HYDROCHLORIDE A',
#  'LIDOCAINE HYDROCHLORIDEEP',
#  'LINCOMYCIN HYDROCHLORIDE',
#  'MIDODRINE HYDROCHLORIDE',
#  'MINOCYCLINE HYDROCHLORIDE',
#  'MITOXANTRONE HYDROCHLORID',
#  'PILOCARPINE HYDROCHLORIDE',
#  'PILOCARPINE HYROCHLORIDE',
#  'PYRIDOXINE HYDROCHLORIDE',
#  'TIAGABINE HYDROCHLORIDE',
#  'BARIUM SULFATE',
#  'FERROUS ASPARTO GLYCINATE',
#  'FERROUS FUMARATE',
#  'FERROUS FUMARATE ASCORBIC',
#  'FERROUS SULFATE',
#  'FERROUS SULFATE DRIED',
#  'TECHNETIUM TC 99M-LABELED',
#  'TECHNETIUM TC-99M',
#  'ARNICA MONTANA MERCURIUS ',
#  'ATOVAQUONE AND PROGUANIL ',
#  'EZETIMIBE AND SIMVASTATIN',
#  'IMPATIENS GLANDULIFERA WH',
#  'LOPINAVIR AND RITONAVIR',
#  'MULTIVITAMIN/MINERAL',
#  'VITAMINS AND MINERALS',
#  'WHITE PETROLATUM MINERAL ',
#  'BENZALKONIUM CHLORIDE',
#  'CALCIUM CHLORIDE',
#  'CETYLPYRIDINIUM CHLORIDE',
#  'CHROMIC CHLORIDE',
#  'ICODEXTRIN SODIUM CHLORID',
#  'ISODIUM CHLORIDE',
#  'MANGANESE CHLORIDE',
#  'METHACHOLINE CHLORIDE',
#  'OXYBUTYNIN CHLORIDE',
#  'POTASSIUM CHLORIDE',
#  'SAMARIUM SM 153 LEXIDRONA',
#  'SODIUM CHLORIDE',
#  'SODIUM CHLORIDE 0',
#  'SODIUM FERRIC GLUCONATE C',
#  'SODIUM FLUORIDE',
#  'SODIUM NITROPRUSSIDE',
#  'SODIUM SULFACETAMIDE',
#  'STRONTIUM CHLORIDE SR-89',
#  'SUCCINYLCHOLINE CHLORIDE',
#  'TROSPIUM CHLORIDE',
#  'CHERYLEE MD SENSITIVE SKI',
#  'CHERYLLEE MD SENSITIVE SK',
#  'ALFUZOSIN HYDROCHLORIDE',
#  'BUPROPION HYDROCHLORIDE',
#  'BUPROPION HYDROCHLORIDE E',
#  'DEXRAZOXANE HYDROCHLORIDE',
#  'DOXORUBICIN HYDROCHLORIDE',
#  'EPIRUBICIN HYDROCHLORIDE',
#  'ERLOTINIB HYDROCHLORIDE',
#  'FLURAZEPAM HYDROCHLORIDE',
#  'GRANISETRON HYDROCHLORIDE',
#  'METFORMIN HYDROCHLORIDE',
#  'MIDAZOLAM HYDROCHLORIDE',
#  'NAPHAZOLINE HYDROCHLORIDE',
#  'NARATRIPTAN HYDROCHLORIDE',
#  'PRAZOSIN HYDROCHLORIDE',
#  'TAMSULOSIN HYDROCHLORIDE',
#  'TERAZOSIN HYDROCHLORIDE',
#  'ACETAMINOPHEN AND CAFFEIN',
#  'ACETAMINOPHEN AND CODEINE',
#  'ACETAMINOPHEN AND DIPHENH',
#  'ACETAMINOPHEN AND PHENYLE',
#  'ACETAMINOPHEN CAFFEINE',
#  'POTASSIUM IODIDE',
#  'POVIDINE IODINE',
#  'POVIDONE IODINE',
#  'POVIDONE-IODINE',
#  'POVIONE IODINE',
#  'PYRITIONE ZINC',
#  'CEFADROXIL MONOHYDRATE',
#  'CITRIC ACID MONOHYDRATE',
#  'NITROFURANTOIN (MONOHYDRA',
#  'NITROFURANTOIN MACROCRYST',
#  'NITROFURANTOIN MONOHYDRAT',
#  'COLLOIDAL OATMEAL',
#  'IODINE ALCOHOLIC',
#  'ISOPROPYL ALCOHOL',
#  'POLYVINYL ALCOHOL',
#  'POLYVINYL ALCOHOL POVIDON',
#  'BACLOFEN',
#  'BUPROPION',
#  'BURN RELIEF',
#  'FLURBIPROFEN',
#  'IBUPFROFEN',
#  'IBUPROFEN',
#  'IBUPROFEN ORAL',
#  'IRON SUPPLEMENT',
#  'KETOPROFEN',
#  'NAPROXEN',
#  'TAZAROTENE',
#  'BROSIMUM ACUTIFOLIUM BARK',
#  'BROSIMUM ACUTIFOLIUM HIMA',
#  'LONICERA CAPRIFOLIUM WHOL',
#  'ALCOHOL',
#  'ALCOHOL 62%',
#  'ALCOHOL 68%',
#  'BETAXOLOL',
#  'BILBERRY',
#  'BISACODYL',
#  'BLACK COHOSH',
#  'CALOMEL',
#  'CAMPHOR',
#  'CARBACHOL',
#  'CROMOLYN',
#  'DOCOSANOL',
#  'ETHYL ALCOHOL',
#  'NADOLOL',
#  'NEBIVOLOL',
#  'PAMABROM',
#  'PHOSPHORUS',
#  'PINDOLOL',
#  'ROYAL JELLY',
#  'TIMOLOL',
#  'URSOSIOL',
#  'ZALEPLON',
#  'ACETAMINOPHEN DIPHENHYDRA',
#  'CALLUS REMOVERS',
#  'CORN REMOVERS',
#  'LIQUID WART REMOVER',
#  'SMALL CORN REMOVERS',
#  'WART REMOVER',
#  'WART REMOVER GEL',
#  'WART REMOVERS',
#  'HYDROCODONE BITARTATE AND',
#  'HYDROCODONE BITARTRATE',
#  'HYDROCODONE BITARTRATE AC',
#  'HYDROCODONE BITARTRATE AN',
#  'HYDROCODONE BITATRATE AND',
#  'ALPRAZOLAM',
#  'BORAGE OIL',
#  'CARBIDOPA',
#  'CHLORASEPTIC',
#  'CLOBAZAM',
#  'CLONAZEPAM',
#  'DIAZEPAM',
#  'ESTAZOLAM',
#  'FILGRASTIM',
#  'LEVETIRACETAM',
#  'LORAZEPAM',
#  'MIDAZOLAM',
#  'NEPAFENAC',
#  'OXAZEPAM',
#  'QUAZEPAM',
#  'SORAFENIB',
#  'TEMAZEPAM',
#  'THIOTEPA',
#  'TOPOTECAN',
#  'TRIAZOLAM',
#  ' SYZYGIUM TEREBINTHINIAE ',
#  'CALCIUM ACETATE',
#  'CALCIUM ASCORBATE DIHYDRA',
#  'CALCIUM CARBONATE',
#  'CALCIUM CARBONATE 750 MG',
#  'CALCIUM GLUCONATE',
#  'CALCIUM POLYCARBOPHIL',
#  'CHARCOAL ACTIVATED',
#  'FAMOTIDINE CALCIUM CARBON',
#  'LANTHANUM CARBONATE',
#  'LITHIUM CARBONATE',
#  'LITHIUM CARBONATE EXTENDE',
#  'MAGNESIUM CARBONATE',
#  'POTASSIUM BICARBONATE',
#  'SEVELAMER CARBONATE',
#  'SODIUM CARBONATE',
#  'CIDOFOVIR ANHYDROUS',
#  'DOCETAXEL ANHYDROUS',
#  'TENOFOVIR DISOPROXIL FUMA',
#  'THEOPHYLLINE ANHYDROUS',
#  'ADENOSINUM CYCLOPHOSPHORI',
#  'AUTOLOGOUS CULTURED CHOND',
#  'BROMUS RAMOSUS WHOLE',
#  'CICHORIUM INTYBUS WHOLE',
#  'JUGLANS REGIA WHOLE',
#  'QUERCUS ROBUR WHOLE',
#  'SCLERANTHUS ANNUUS WHOLE',
#  'TUBERCULIN PURIFIED PROTE',
#  'ULMUS MINOR WHOLE',
#  'METHYLERGONOVINE MALEATE',
#  'METHYLPREDNISOLONE',
#  'METHYLPREDNISOLONE ACETAT',
#  'METHYLPREDNISOLONE SODIUM',
#  'PREDNISOLONE ACETATE',
#  'EUPATORIUM PERFOLIATUM FL',
#  'HYPERICUM PERFORATUM',
#  'ONION EUPATORIUM PERFOLIA',
#  'ANTIHEMOPHILIC FACTOR REC',
#  'BOSYE BENEFITING HAIR LOT',
#  'BRIMONIDINE TARTRATE',
#  'BRIMONIDINE TARTRATE TIMO',
#  'ERGOTAMINE TARTRATE AND C',
#  'NOREPINEPHRINE BITARTRATE',
#  'RIVASTIGMINE TARTRATE',
#  'TOLTERODINE TARTRATE',
#  'VARENICLINE TARTRATE',
#  'VINORELBINE TARTRATE',
#  'CARPINUS BETULUS WHOLE',
#  'FAGUS SYLVATICA WHOLE',
#  'HOTTONIA PALUSTRIS WHOLE',
#  'PINUS SYLVESTRIS WHOLE',
#  'PRUNUS CERASIFERA WHOLE',
#  'SINAPIS ARVENSIS WHOLE',
#  'CARBOXYMETHYLCELLULOSE SO',
#  'METHYLCELLULOSE',
#  'METHYLENE BLUE',
#  'ACETAMINOPHEN DEXTROMETHO',
#  'AESCULUS X CARNEA WHOLE',
#  'CALLUNA VULGARIS WHOLE',
#  'CANDIDA ALBICANS WOOD CRE',
#  'CASTANEA SATIVA WHOLE',
#  'CLEMATIS VITALBA WHOLE',
#  'GENTIANELLA AMARELLA WHOL',
#  'LARIX DECIDUA WHOLE',
#  'MALUS PUMILA WHOLE',
#  'ROSA CANINA WHOLE',
#  'SALIX ALBA WHOLE',
#  'VITIS VINIFERA WHOLE',
#  'ALLANTOIN',
#  'ANIDULAFUNGIN',
#  'ARGATROBAN',
#  'AURANOFIN',
#  'BECAPLERMIN',
#  'BELLADONNA',
#  'CEFADROXIL',
#  'CEFAZOLIN',
#  'CELECOXIB',
#  'CEPHALEXIN',
#  'DASATINIB',
#  'GEFITINIB',
#  'IVERMECTIN',
#  'LANOLIN',
#  'LAPATINIB',
#  'MEBROFENIN',
#  'MECASERMIN',
#  'MELALEUCA',
#  'MELATONIN',
#  'MENOTROPINS',
#  'MERCAPTOPURINE',
#  'METFORMIN',
#  'MODAFINIL',
#  'MUPIROCIN',
#  'NILOTINIB',
#  'OXYBUTYNIN',
#  'OXYTOCIN',
#  'SILODOSIN',
#  'UROFOLLITROPIN',
#  'AMITRIPTYLINE HYDROCHLORI',
#  'BUPRENORPHINE AND NALOXON',
#  'BUPRENORPHINE HYDROCHLORI',
#  'DIPHENOXYLATE HYDROCHLORI',
#  'HYDROMORPHONE HYDROCHLORI',
#  'NORTRIPTYLINE HYDROCHLORI',
#  'PHENYLEPHRINE HYDROCHLORI',
#  'BENDAMUSTINE HYDROCHLORID',
#  'BUSPIRONE HYDROCHLORIDE',
#  'CEFEPIME HYDROCHLORIDE',
#  'COCAINE HYDROCHLORIDE',
#  'DESIPRAMINE HYDROCHLORIDE',
#  'DHEA (DEHYDROEPIANDROSTER',
#  'DICYCLOMINE HYDROCHLORIDE',
#  'DILTIAZEM HYDROCHLORIDE',
#  'DOBUTAMINE HYDROCHLORIDE',
#  'DONEPEZIL HYDROCHLORIDE',
#  'DOPAMINE HYDROCHLORIDE',
#  'DORZOLAMIDE HYDROCHLORIDE',
#  'DOXAPRAM HYDROCHLORIDE',
#  'DOXEPIN HYDROCHLORIDE',
#  'IMIPRAMINE HYDROCHLORIDE',
#  'KETAMINE HYDROCHLORIDE',
#  'LOPERAMIDE HYDROCHLORIDE',
#  'LOPERAMIDE HYDROCHLORIDE ',
#  'MELPHALAN HYDROCHLORIDE',
#  'OLOPATADINE HYDROCHLORIDE',
#  'ROPINIROLE HYDROCHLORIDE',
#  'THIAMINE HYDROCHLORIDE',
#  'THIAMINE HYDROCHLORIDE RI',
#  'VERAPAMIL HYDROCHLORIDE',
#  'ZIPRASIDONE HYDROCHLORIDE',
#  'CHOLESTYRAMINE',
#  'CYPROHEPTADINE',
#  'FLUOROMETHOLONE',
#  'FOSFOMYCIN TROMETHAMINE',
#  'INDOMETHACIN',
#  'KETOROLAC TROMETHAMINE',
#  'MOMETASONE',
#  'PERMETHRIN',
#  'PERPHENAZINE',
#  'PIOGLITAZONE',
#  'PROCHLORPERAZINE',
#  'PROMETHAZINE',
#  'PROMETHAZINE HCL',
#  'PROPYLTHIOURACIL',
#  'PYRIMETHAMINE',
#  'SIMETHICONE',
#  'TRIMETHOPRIM',
#  'DEXTROAMPHETAMINE SACCHAR',
#  'DEXTROAMPHETAMINE SULFATE',
#  '3% DICLOFENAC SPRAY',
#  'DICLOFENAC EPOLAMINE',
#  'DICLOFENAC POTASSIUM',
#  'DICLOFENAC SODIUM',
#  'DICLOFENAC SODIUM AND MIS',
#  'METHOHEXITAL SODIUM',
#  'MICAFUNGIN SODIUM',
#  'MONTELUKAST SODIUM',
#  'CAIRINA MOSCHATA HEART/LI',
#  'CODEINE PHOSPHATE AND GUA',
#  'POTASSIUM PHOSPHATE MONOB',
#  'SODIUM PHOSPHATE MONOBASI',
#  ' VERATRUM ALB',
#  'ABCIXIMAB',
#  'ADALIMUMAB',
#  'ALEMTUZUMAB',
#  'ALOE ARSENICUM ALB',
#  'ANTIFUNGAL',
#  'BASILIXIMAB',
#  'BEVACIZUMAB',
#  'CERTOLIZUMAB PEGOL',
#  'DACLIZUMAB',
#  'DICLOFENAC',
#  'DIFLUNISAL',
#  'ECULIZUMAB',
#  'IPILIMUMAB',
#  'NATALIZUMAB',
#  'OMALIZUMAB',
#  'PACLITAXEL',
#  'PALIVIZUMAB',
#  'PANITUMUMAB',
#  'RANIBIZUMAB',
#  'TRASTUZUMAB',
#  'VALACYCLOVIR HYDROCHLORID',
#  'VALGANCICLOVIR HYDROCHLOR',
#  'FOLLICULINUM OOPHORINUM',
#  'FOLLICULINUM OOPHORINUM (',
#  'CARBOPLATIN INJECTION',
#  'CERATOSTIGMA WILLMOTTIANU',
#  'DEXRAZOXANE FOR INJECTION',
#  'ETOMIDATE INJECTION',
#  'LEVETIRACETAM INJECTION',
#  'MESNA INJECTION',
#  'VERTEPORFIN FOR INJECTION',
#  'ACYCLOVIR SODIUM',
#  'AMPICILLIN SODIUM',
#  'BACILLUS SUBTILIS',
#  'CROMOLYN SODIUM',
#  'DICLOXACILLIN SODIUM',
#  'FLUVASTATIN SODIUM',
#  'GANCICLOVIR SODIUM',
#  'NAFCILLIN SODIUM',
#  'OLSALAZINE SODIUM',
#  'OXACILLIN SODIUM',
#  'PRAVASTATIN SODIUM',
#  'INTERFERON (SUIS)',
#  'INTERFERON ALFA-2A',
#  'INTERFERON ALFA-2B',
#  'INTERFERON BETA-1A',
#  'INTERFERON BETA-1B',
#  'PEGINTERFERON ALFA-2A',
#  'PEGINTERFERON ALFA-2B',
#  'ALLIUM SATIVUM',
#  'CAFFEINE CITRATE',
#  'CLOMIPHENE CITRATE',
#  'COLISTIMETHATE',
#  'DEADLY NIGHTSHADE',
#  'LITHIUM BROMATUM',
#  'POTASSIUM CITRATE',
#  'SILVER NITRATE',
#  'SODIUM BICARBONATE',
#  'SODIUM CITRATE',
#  'SODIUM HYALURONATE',
#  'SODIUM LACTATE',
#  'SODIUM OXYBATE',
#  'TAMOXIFEN CITRATE',
#  'ZOLPIDEM TARTRATE',
#  'CENTAURIUM ERYTHRAEA',
#  'FENTANYL CITRATE',
#  'FENTANYL IONTOPHORETIC TR',
#  'SILDENAFIL CITRATE',
#  'SUFENTANIL CITRATE',
#  'DOXYCLYCLINE HYCLATE',
#  'DOXYCYCLINE HYCLATE',
#  'DOXYLAMINE SUCCINATE',
#  'ILEX AQUIFOLIUM WHOLE',
#  'MIMULUS GUTTATUS WHOLE',
#  'OLEA EUROPAEA WHOLE',
#  'POPULUS TREMULOIDES WHOLE',
#  'ULEX EUROPAEUS WHOLE',
#  'AMLODIPINE',
#  'AMOXAPINE',
#  'ANAKINRA',
#  'ATOVAQUONE',
#  'ATROPINE',
#  'CARBAMAZEPINE',
#  'CLOZAPINE',
#  ...]

# %%
cluster_list
# Out:
# ['MAGNESIUM SULFATE',
#  'MAGNESIUM SULFATE',
#  'MAGNESIUM SULFATE',
#  'MAGNESIUM SULFATE',
#  'MAGNESIUM SULFATE',
#  'MAGNESIUM SULFATE',
#  'MAGNESIUM SULFATE',
#  'MAGNESIUM SULFATE',
#  'MAGNESIUM SULFATE',
#  'CHORIONIC GONADOTROPIN',
#  'CHORIONIC GONADOTROPIN',
#  'CHORIONIC GONADOTROPIN',
#  'AMLODIPINE BESYLATE AND V',
#  'AMLODIPINE BESYLATE AND V',
#  'AMLODIPINE BESYLATE AND V',
#  'AMLODIPINE BESYLATE AND V',
#  'AMLODIPINE BESYLATE AND V',
#  'PSEUDOEPHEDRINE HCL',
#  'PSEUDOEPHEDRINE HCL',
#  'PSEUDOEPHEDRINE HCL',
#  'PSEUDOEPHEDRINE HCL',
#  'ONE STEP WART REMOVER',
#  'ONE STEP WART REMOVER',
#  'ONE STEP WART REMOVER',
#  'ONE STEP WART REMOVER',
#  'ONE STEP WART REMOVER',
#  'ONE STEP WART REMOVER',
#  'ONE STEP WART REMOVER',
#  'BECLOMETHASONE DIPROPIONA',
#  'BECLOMETHASONE DIPROPIONA',
#  'BECLOMETHASONE DIPROPIONA',
#  'CAFFEINE MAGNESIUM SALICY',
#  'CAFFEINE MAGNESIUM SALICY',
#  'MENTHOL',
#  'MENTHOL',
#  'MENTHOL',
#  'MENTHOL',
#  'MENTHOL',
#  'MENTHOL',
#  'MENTHOL',
#  'MENTHOL',
#  'MENTHOL',
#  'MENTHOL',
#  'MENTHOL',
#  'MENTHOL',
#  'MENTHOL',
#  'MENTHOL',
#  'MENTHOL',
#  'MENTHOL',
#  'MENTHOL',
#  'MENTHOL',
#  'MENTHOL',
#  'MENTHOL',
#  'MENTHOL',
#  'MENTHOL',
#  'MENTHOL',
#  'ACONITUM NAPELLUS ARSENIC',
#  'ACONITUM NAPELLUS ARSENIC',
#  'IBUPROFEN SODIUM',
#  'IBUPROFEN SODIUM',
#  'IBUPROFEN SODIUM',
#  'IBUPROFEN SODIUM',
#  'IBUPROFEN SODIUM',
#  'IBUPROFEN SODIUM',
#  'IBUPROFEN SODIUM',
#  'IBUPROFEN SODIUM',
#  'IBUPROFEN SODIUM',
#  'IBUPROFEN SODIUM',
#  'IBUPROFEN SODIUM',
#  'IBUPROFEN SODIUM',
#  'IBUPROFEN SODIUM',
#  'IBUPROFEN SODIUM',
#  'IBUPROFEN SODIUM',
#  'IBUPROFEN SODIUM',
#  'OLMESARTAN MEDOXOMIL',
#  'OLMESARTAN MEDOXOMIL',
#  'OLMESARTAN MEDOXOMIL',
#  'FLECAINIDE ACETATE',
#  'FLECAINIDE ACETATE',
#  'FLECAINIDE ACETATE',
#  'FLECAINIDE ACETATE',
#  'FLECAINIDE ACETATE',
#  'FLECAINIDE ACETATE',
#  'FLECAINIDE ACETATE',
#  'OXACILLIN',
#  'OXACILLIN',
#  'OXACILLIN',
#  'OXACILLIN',
#  'OXACILLIN',
#  'OXACILLIN',
#  'OXACILLIN',
#  'OXACILLIN',
#  'OXACILLIN',
#  'OXACILLIN',
#  'OXACILLIN',
#  'OXACILLIN',
#  'OXACILLIN',
#  'IMIPRAMINE PAMOATE',
#  'IMIPRAMINE PAMOATE',
#  'IMIPRAMINE PAMOATE',
#  'IMIPRAMINE PAMOATE',
#  'IMIPRAMINE PAMOATE',
#  'IMIPRAMINE PAMOATE',
#  'IMIPRAMINE PAMOATE',
#  'IMIPRAMINE PAMOATE',
#  'ZINC OXIDE',
#  'ZINC OXIDE',
#  'ZINC OXIDE',
#  'ZINC OXIDE',
#  'ZINC OXIDE',
#  'ZINC OXIDE',
#  'ZINC OXIDE',
#  'ZINC OXIDE',
#  'ZINC OXIDE',
#  'ZINC OXIDE',
#  'ZINC OXIDE',
#  'ZINC OXIDE',
#  'ZINC OXIDE',
#  'ZINC OXIDE',
#  'ZINC OXIDE',
#  'ZINC OXIDE',
#  'ASPIRIN AND CAFFEINE',
#  'ASPIRIN AND CAFFEINE',
#  'ASPIRIN AND CAFFEINE',
#  'ASPIRIN AND CAFFEINE',
#  'ASPIRIN AND CAFFEINE',
#  'ASPIRIN AND CAFFEINE',
#  'ASPIRIN AND CAFFEINE',
#  'ASPIRIN AND CAFFEINE',
#  'ASPIRIN AND CAFFEINE',
#  'ASPIRIN AND CAFFEINE',
#  'ASPIRIN AND CAFFEINE',
#  'ASPIRIN AND CAFFEINE',
#  'ASPIRIN AND CAFFEINE',
#  'IPRATROPIUM BROMIDE',
#  'IPRATROPIUM BROMIDE',
#  'IPRATROPIUM BROMIDE',
#  'IPRATROPIUM BROMIDE',
#  'IPRATROPIUM BROMIDE',
#  'IPRATROPIUM BROMIDE',
#  'IPRATROPIUM BROMIDE',
#  'IPRATROPIUM BROMIDE',
#  'IPRATROPIUM BROMIDE',
#  'IPRATROPIUM BROMIDE',
#  'IPRATROPIUM BROMIDE',
#  'ORNITHOGALUM UMBELLATUM H',
#  'ORNITHOGALUM UMBELLATUM H',
#  'ORNITHOGALUM UMBELLATUM H',
#  'RANITIDINE',
#  'RANITIDINE',
#  'RANITIDINE',
#  'RANITIDINE',
#  'RANITIDINE',
#  'RANITIDINE',
#  'RANITIDINE',
#  'RANITIDINE',
#  'RANITIDINE',
#  'RANITIDINE',
#  'RANITIDINE',
#  'RANITIDINE',
#  'RANITIDINE',
#  'RANITIDINE',
#  'RANITIDINE',
#  'RANITIDINE',
#  'RANITIDINE',
#  'RANITIDINE',
#  'RANITIDINE',
#  'RANITIDINE',
#  'RANITIDINE',
#  'RANITIDINE',
#  'RANITIDINE',
#  'RANITIDINE',
#  'DEFEROXAMINE MESYLATE',
#  'DEFEROXAMINE MESYLATE',
#  'DEFEROXAMINE MESYLATE',
#  'DEFEROXAMINE MESYLATE',
#  'DEFEROXAMINE MESYLATE',
#  'DEFEROXAMINE MESYLATE',
#  'DEFEROXAMINE MESYLATE',
#  'THALLOUS CHLORIDE TL-201',
#  'THALLOUS CHLORIDE TL-201',
#  'BISOPROLOL FUMARATE',
#  'BISOPROLOL FUMARATE',
#  'BISOPROLOL FUMARATE',
#  'BISOPROLOL FUMARATE',
#  'BISOPROLOL FUMARATE',
#  'DIPHENHYDRAMINE CITRATE I',
#  'DIPHENHYDRAMINE CITRATE I',
#  'DIPHENHYDRAMINE CITRATE I',
#  'TOLNAFTATE JOCK ITCH POWD',
#  'TOLNAFTATE JOCK ITCH POWD',
#  'TOLNAFTATE JOCK ITCH POWD',
#  'ESTRADIOL CYPIONATE',
#  'ESTRADIOL CYPIONATE',
#  'ESTRADIOL CYPIONATE',
#  'ESTRADIOL CYPIONATE',
#  'ESTRADIOL CYPIONATE',
#  'ESTRADIOL CYPIONATE',
#  'ESTRADIOL CYPIONATE',
#  'ESTRADIOL CYPIONATE',
#  'RASAGILINE MESYLATE',
#  'RASAGILINE MESYLATE',
#  'RASAGILINE MESYLATE',
#  'RASAGILINE MESYLATE',
#  'RASAGILINE MESYLATE',
#  'RASAGILINE MESYLATE',
#  'RASAGILINE MESYLATE',
#  'RASAGILINE MESYLATE',
#  'RASAGILINE MESYLATE',
#  'RASAGILINE MESYLATE',
#  'ALUMINUM HYDROXIDE AND MA',
#  'ALUMINUM HYDROXIDE AND MA',
#  'ALUMINUM HYDROXIDE AND MA',
#  'SALSALATE',
#  'SALSALATE',
#  'SALSALATE',
#  'SALSALATE',
#  'SALSALATE',
#  'SALSALATE',
#  'SALSALATE',
#  'SALSALATE',
#  'SALSALATE',
#  'SALSALATE',
#  'SALSALATE',
#  'SALSALATE',
#  'SALSALATE',
#  'SALSALATE',
#  'SALSALATE',
#  'SALSALATE',
#  'SALSALATE',
#  'SALSALATE',
#  'SALSALATE',
#  'SALSALATE',
#  'VITAMIN A ASCORBIC ACID C',
#  'VITAMIN A ASCORBIC ACID C',
#  'VITAMIN A ASCORBIC ACID C',
#  'HALOPERIDOL DECANOATE',
#  'HALOPERIDOL DECANOATE',
#  'HALOPERIDOL DECANOATE',
#  'HALOPERIDOL DECANOATE',
#  'HALOPERIDOL DECANOATE',
#  'SODIUM PHOSPHATE',
#  'SODIUM PHOSPHATE',
#  'SODIUM PHOSPHATE',
#  'SODIUM PHOSPHATE',
#  'SODIUM PHOSPHATE',
#  'SODIUM PHOSPHATE',
#  'SODIUM PHOSPHATE',
#  'SODIUM PHOSPHATE',
#  'SODIUM PHOSPHATE',
#  'SODIUM PHOSPHATE',
#  'SODIUM PHOSPHATE',
#  'PROTAMINE SULFATE',
#  'PROTAMINE SULFATE',
#  'PROTAMINE SULFATE',
#  'PROTAMINE SULFATE',
#  'PROTAMINE SULFATE',
#  'PROTAMINE SULFATE',
#  'PROTAMINE SULFATE',
#  'PROTAMINE SULFATE',
#  'PROTAMINE SULFATE',
#  'PROTAMINE SULFATE',
#  'PROTAMINE SULFATE',
#  'PROTAMINE SULFATE',
#  'PROTAMINE SULFATE',
#  'PROTAMINE SULFATE',
#  'PROTAMINE SULFATE',
#  'PROTAMINE SULFATE',
#  'PROTAMINE SULFATE',
#  'PROTAMINE SULFATE',
#  'PROTAMINE SULFATE',
#  'PROTAMINE SULFATE',
#  'PROTAMINE SULFATE',
#  'PROTAMINE SULFATE',
#  'PROTAMINE SULFATE',
#  'PROTAMINE SULFATE',
#  'PROTAMINE SULFATE',
#  'DEXTROMETHORPHAN HBR AND ',
#  'DEXTROMETHORPHAN HBR AND ',
#  'DEXTROMETHORPHAN HBR AND ',
#  'DEXTROMETHORPHAN HBR AND ',
#  'DEXTROMETHORPHAN HBR AND ',
#  'DEXTROMETHORPHAN HBR AND ',
#  'ACETAMINOPHEN ASPIRIN CAF',
#  'ACETAMINOPHEN ASPIRIN CAF',
#  'ACETAMINOPHEN ASPIRIN CAF',
#  'ACETAMINOPHEN ASPIRIN CAF',
#  'ACETAMINOPHEN ASPIRIN CAF',
#  'ACETAMINOPHEN ASPIRIN CAF',
#  'LIOTHYRONINE SODIUM',
#  'LIOTHYRONINE SODIUM',
#  'LIOTHYRONINE SODIUM',
#  'LIOTHYRONINE SODIUM',
#  'LIOTHYRONINE SODIUM',
#  'BUTALBITAL ASPIRIN AND CA',
#  'BUTALBITAL ASPIRIN AND CA',
#  'CEFIXIME',
#  'CEFIXIME',
#  'CEFIXIME',
#  'CEFIXIME',
#  'CEFIXIME',
#  'CEFIXIME',
#  'CEFIXIME',
#  'CEFIXIME',
#  'CEFIXIME',
#  'CEFIXIME',
#  'CEFIXIME',
#  'CEFIXIME',
#  'CEFIXIME',
#  'CEFIXIME',
#  'CEFIXIME',
#  'CEFIXIME',
#  'CEFIXIME',
#  'CEFIXIME',
#  'CEFIXIME',
#  'CEFIXIME',
#  'CEFIXIME',
#  'ABACAVIR',
#  'ABACAVIR',
#  'ABACAVIR',
#  'ABACAVIR',
#  'ABACAVIR',
#  'ABACAVIR',
#  'ABACAVIR',
#  'ABACAVIR',
#  'ABACAVIR',
#  'ABACAVIR',
#  'ABACAVIR',
#  'ABACAVIR',
#  'ABACAVIR',
#  'ABACAVIR',
#  'ABACAVIR',
#  'DEXTROMETHORPHAN HYDROBRO',
#  'FLUTICASONE PROPIONATE',
#  'FLUTICASONE PROPIONATE',
#  'FLUTICASONE PROPIONATE',
#  'FLUTICASONE PROPIONATE',
#  'PANTOPRAZOLE SODIUM',
#  'PANTOPRAZOLE SODIUM',
#  'PANTOPRAZOLE SODIUM',
#  'PANTOPRAZOLE SODIUM',
#  'PANTOPRAZOLE SODIUM',
#  'PANTOPRAZOLE SODIUM',
#  'PANTOPRAZOLE SODIUM',
#  'PANTOPRAZOLE SODIUM',
#  'PANTOPRAZOLE SODIUM',
#  'OXYCODONE HYDROCHLORIDE',
#  'OXYCODONE HYDROCHLORIDE',
#  'OXYCODONE HYDROCHLORIDE',
#  'OXYCODONE HYDROCHLORIDE',
#  'OXYCODONE HYDROCHLORIDE',
#  'OXYCODONE HYDROCHLORIDE',
#  'OXYCODONE HYDROCHLORIDE',
#  'OXYCODONE HYDROCHLORIDE',
#  'OXYCODONE HYDROCHLORIDE',
#  'OXYCODONE HYDROCHLORIDE',
#  'OXYCODONE HYDROCHLORIDE',
#  'FOOT ODOR CONTROL SPRAY',
#  'FOOT ODOR CONTROL SPRAY',
#  'FOOT ODOR CONTROL SPRAY',
#  'ZINC GLUCONATE ROSA CANIN',
#  'ZINC GLUCONATE ROSA CANIN',
#  'ZINC GLUCONATE ROSA CANIN',
#  'ZINC GLUCONATE ROSA CANIN',
#  'ZINC GLUCONATE ROSA CANIN',
#  'LOTEPREDNOL ETABONATE AND',
#  'LOTEPREDNOL ETABONATE AND',
#  'TRETINOIN',
#  'TRETINOIN',
#  'TRETINOIN',
#  'TRETINOIN',
#  'TRETINOIN',
#  'TRETINOIN',
#  'TRETINOIN',
#  'TRETINOIN',
#  'TRETINOIN',
#  'TRETINOIN',
#  'TRETINOIN',
#  'TRETINOIN',
#  'TRETINOIN',
#  'TRETINOIN',
#  'TRETINOIN',
#  'TRETINOIN',
#  'TRETINOIN',
#  'TRETINOIN',
#  'TRETINOIN',
#  'TRETINOIN',
#  'TRETINOIN',
#  'TRETINOIN',
#  'TRETINOIN',
#  'SUMATRIPTAN SUCCINATE',
#  'SUMATRIPTAN SUCCINATE',
#  'SUMATRIPTAN SUCCINATE',
#  'SUMATRIPTAN SUCCINATE',
#  'SUMATRIPTAN SUCCINATE',
#  'SUMATRIPTAN SUCCINATE',
#  'SUMATRIPTAN SUCCINATE',
#  'BOSENTAN',
#  'BOSENTAN',
#  'BOSENTAN',
#  'BOSENTAN',
#  'BOSENTAN',
#  'BOSENTAN',
#  'BOSENTAN',
#  'BOSENTAN',
#  'BOSENTAN',
#  'BOSENTAN',
#  'BOSENTAN',
#  'BOSENTAN',
#  'BOSENTAN',
#  'BOSENTAN',
#  'BOSENTAN',
#  'BOSENTAN',
#  'BOSENTAN',
#  'BOSENTAN',
#  'BOSENTAN',
#  'BOSENTAN',
#  'BOSENTAN',
#  'BOSENTAN',
#  'ISOSORBIDE MONONITRATE',
#  'ISOSORBIDE MONONITRATE',
#  'ISOSORBIDE MONONITRATE',
#  'ISOSORBIDE MONONITRATE',
#  'CARBAMIDE PEROXIDE',
#  'CARBAMIDE PEROXIDE',
#  'CARBAMIDE PEROXIDE',
#  'CARBAMIDE PEROXIDE',
#  'ANTIFUNGAL MICONAZOLE LIQ',
#  'ANTIFUNGAL MICONAZOLE LIQ',
#  'ANTIFUNGAL MICONAZOLE LIQ',
#  'ANTIFUNGAL MICONAZOLE LIQ',
#  'ANTIFUNGAL MICONAZOLE LIQ',
#  'ANTIFUNGAL MICONAZOLE LIQ',
#  'METHAZOLAMIDE',
#  'METHAZOLAMIDE',
#  'METHAZOLAMIDE',
#  'METHAZOLAMIDE',
#  'METHAZOLAMIDE',
#  'METHAZOLAMIDE',
#  'METHAZOLAMIDE',
#  'METHAZOLAMIDE',
#  'METHAZOLAMIDE',
#  'METHAZOLAMIDE',
#  'METHAZOLAMIDE',
#  'METHAZOLAMIDE',
#  'METHAZOLAMIDE',
#  'METHAZOLAMIDE',
#  'METHAZOLAMIDE',
#  'METHAZOLAMIDE',
#  'PIOGLITAZONE AND METFORMI',
#  'PIOGLITAZONE AND METFORMI',
#  'PIOGLITAZONE AND METFORMI',
#  'PIOGLITAZONE AND METFORMI',
#  'PIOGLITAZONE AND METFORMI',
#  'PIOGLITAZONE AND METFORMI',
#  'PIOGLITAZONE AND METFORMI',
#  'IRBESARTAN AND HYDROCHLOR',
#  'IRBESARTAN AND HYDROCHLOR',
#  'IRBESARTAN AND HYDROCHLOR',
#  'IRBESARTAN AND HYDROCHLOR',
#  'IRBESARTAN AND HYDROCHLOR',
#  'TETRACAINE HYDROCHLORIDE',
#  'TETRACAINE HYDROCHLORIDE',
#  'TETRACAINE HYDROCHLORIDE',
#  'TETRACAINE HYDROCHLORIDE',
#  'TETRACAINE HYDROCHLORIDE',
#  'TETRACAINE HYDROCHLORIDE',
#  'TETRACAINE HYDROCHLORIDE',
#  'TETRACAINE HYDROCHLORIDE',
#  'TETRACAINE HYDROCHLORIDE',
#  'TETRACAINE HYDROCHLORIDE',
#  'TETRACAINE HYDROCHLORIDE',
#  'TETRACAINE HYDROCHLORIDE',
#  'TETRACAINE HYDROCHLORIDE',
#  'TETRACAINE HYDROCHLORIDE',
#  'TETRACAINE HYDROCHLORIDE',
#  'TETRACAINE HYDROCHLORIDE',
#  'GUAIFENESIN AND DEXTROMET',
#  'GUAIFENESIN AND DEXTROMET',
#  'GUAIFENESIN AND DEXTROMET',
#  'GUAIFENESIN AND DEXTROMET',
#  'NORETHINDRONE ACETATE AND',
#  'NORETHINDRONE ACETATE AND',
#  'NORETHINDRONE ACETATE AND',
#  'NORETHINDRONE ACETATE AND',
#  'NORETHINDRONE ACETATE AND',
#  'NORETHINDRONE ACETATE AND',
#  'BUPIVACAINE HYDROCHLORIDE',
#  'BUPIVACAINE HYDROCHLORIDE',
#  'BUPIVACAINE HYDROCHLORIDE',
#  'BUPIVACAINE HYDROCHLORIDE',
#  'BUPIVACAINE HYDROCHLORIDE',
#  'NICOTINE POLACRILEX',
#  'NICOTINE POLACRILEX',
#  'NICOTINE POLACRILEX',
#  'HYDROCORTISONE ACETATE',
#  'HYDROCORTISONE ACETATE',
#  'HYDROCORTISONE ACETATE',
#  'HYDROCORTISONE ACETATE',
#  'HYDROCORTISONE ACETATE',
#  'HYDROCORTISONE ACETATE',
#  'HYDROCORTISONE ACETATE',
#  'HYDROCORTISONE ACETATE',
#  'HYDROCORTISONE ACETATE',
#  'HYDROCORTISONE ACETATE',
#  'HYDROCORTISONE ACETATE',
#  'HYDROCORTISONE ACETATE',
#  'HYDROCORTISONE ACETATE',
#  'INSULIN HUMAN',
#  'INSULIN HUMAN',
#  'INSULIN HUMAN',
#  'INSULIN HUMAN',
#  'INSULIN HUMAN',
#  'INSULIN HUMAN',
#  'INSULIN HUMAN',
#  'INSULIN HUMAN',
#  'INSULIN HUMAN',
#  'INSULIN HUMAN',
#  'INSULIN HUMAN',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'MYCOPHENOLATE MOFETIL',
#  'MYCOPHENOLATE MOFETIL',
#  'MYCOPHENOLATE MOFETIL',
#  'MYCOPHENOLATE MOFETIL',
#  'PENICILLIN G PROCAINE',
#  'PENICILLIN G PROCAINE',
#  'PENICILLIN G PROCAINE',
#  'CITALOPRAM TABLETS',
#  'CITALOPRAM TABLETS',
#  'CITALOPRAM TABLETS',
#  'CITALOPRAM TABLETS',
#  'CITALOPRAM TABLETS',
#  'CITALOPRAM TABLETS',
#  'CITALOPRAM TABLETS',
#  'PYRETHRUM EXTRACT AND PIP',
#  'PYRETHRUM EXTRACT AND PIP',
#  'FENTANYL TRANSDERMAL SYST',
#  'FENTANYL TRANSDERMAL SYST',
#  '5 MG',
#  '5 MG',
#  '5 MG',
#  '5 MG',
#  '5 MG',
#  '5 MG',
#  '5 MG',
#  '5 MG',
#  '5 MG',
#  '5 MG',
#  '5 MG',
#  '5 MG',
#  'BETHANECHOL CHLORIDE 50 M',
#  'BETHANECHOL CHLORIDE 50 M',
#  'BETHANECHOL CHLORIDE 50 M',
#  'BETHANECHOL CHLORIDE 50 M',
#  'BETHANECHOL CHLORIDE 50 M',
#  'OMEPRAZOLE MAGNESIUM',
#  'OMEPRAZOLE MAGNESIUM',
#  'OMEPRAZOLE MAGNESIUM',
#  'OMEPRAZOLE MAGNESIUM',
#  'OMEPRAZOLE MAGNESIUM',
#  'METHYLPHENIDATE HYDROCHLO',
#  'METHYLPHENIDATE HYDROCHLO',
#  'METHYLPHENIDATE HYDROCHLO',
#  'METHYLPHENIDATE HYDROCHLO',
#  'METHYLPHENIDATE HYDROCHLO',
#  'METHYLPHENIDATE HYDROCHLO',
#  'POLYETHYLENE GLYCOL 3350',
#  'POLYETHYLENE GLYCOL 3350',
#  'POLYETHYLENE GLYCOL 3350',
#  'POLYETHYLENE GLYCOL 3350',
#  'POLYETHYLENE GLYCOL 3350',
#  'POLYETHYLENE GLYCOL 3350',
#  'POLYETHYLENE GLYCOL 3350',
#  'POLYETHYLENE GLYCOL 3350',
#  'LIDOCAINE HYDROCHLORIDE',
#  'LIDOCAINE HYDROCHLORIDE',
#  'LIDOCAINE HYDROCHLORIDE',
#  'LIDOCAINE HYDROCHLORIDE',
#  'LIDOCAINE HYDROCHLORIDE',
#  'LIDOCAINE HYDROCHLORIDE',
#  'LIDOCAINE HYDROCHLORIDE',
#  'LIDOCAINE HYDROCHLORIDE',
#  'LIDOCAINE HYDROCHLORIDE',
#  'LIDOCAINE HYDROCHLORIDE',
#  'LIDOCAINE HYDROCHLORIDE',
#  'LIDOCAINE HYDROCHLORIDE',
#  'LIDOCAINE HYDROCHLORIDE',
#  'LIDOCAINE HYDROCHLORIDE',
#  'LIDOCAINE HYDROCHLORIDE',
#  'LIDOCAINE HYDROCHLORIDE',
#  'LIDOCAINE HYDROCHLORIDE',
#  'LIDOCAINE HYDROCHLORIDE',
#  'FERROUS SULFATE',
#  'FERROUS SULFATE',
#  'FERROUS SULFATE',
#  'FERROUS SULFATE',
#  'FERROUS SULFATE',
#  'FERROUS SULFATE',
#  'TECHNETIUM TC 99M-LABELED',
#  'TECHNETIUM TC 99M-LABELED',
#  'VITAMINS AND MINERALS',
#  'VITAMINS AND MINERALS',
#  'VITAMINS AND MINERALS',
#  'VITAMINS AND MINERALS',
#  'VITAMINS AND MINERALS',
#  'VITAMINS AND MINERALS',
#  'VITAMINS AND MINERALS',
#  'VITAMINS AND MINERALS',
#  'SODIUM CHLORIDE',
#  'SODIUM CHLORIDE',
#  'SODIUM CHLORIDE',
#  'SODIUM CHLORIDE',
#  'SODIUM CHLORIDE',
#  'SODIUM CHLORIDE',
#  'SODIUM CHLORIDE',
#  'SODIUM CHLORIDE',
#  'SODIUM CHLORIDE',
#  'SODIUM CHLORIDE',
#  'SODIUM CHLORIDE',
#  'SODIUM CHLORIDE',
#  'SODIUM CHLORIDE',
#  'SODIUM CHLORIDE',
#  'SODIUM CHLORIDE',
#  'SODIUM CHLORIDE',
#  'SODIUM CHLORIDE',
#  'SODIUM CHLORIDE',
#  'SODIUM CHLORIDE',
#  'SODIUM CHLORIDE',
#  'CHERYLEE MD SENSITIVE SKI',
#  'CHERYLEE MD SENSITIVE SKI',
#  'PRAZOSIN HYDROCHLORIDE',
#  'PRAZOSIN HYDROCHLORIDE',
#  'PRAZOSIN HYDROCHLORIDE',
#  'PRAZOSIN HYDROCHLORIDE',
#  'PRAZOSIN HYDROCHLORIDE',
#  'PRAZOSIN HYDROCHLORIDE',
#  'PRAZOSIN HYDROCHLORIDE',
#  'PRAZOSIN HYDROCHLORIDE',
#  'PRAZOSIN HYDROCHLORIDE',
#  'PRAZOSIN HYDROCHLORIDE',
#  'PRAZOSIN HYDROCHLORIDE',
#  'PRAZOSIN HYDROCHLORIDE',
#  'PRAZOSIN HYDROCHLORIDE',
#  'PRAZOSIN HYDROCHLORIDE',
#  'PRAZOSIN HYDROCHLORIDE',
#  'PRAZOSIN HYDROCHLORIDE',
#  'ACETAMINOPHEN AND CODEINE',
#  'ACETAMINOPHEN AND CODEINE',
#  'ACETAMINOPHEN AND CODEINE',
#  'ACETAMINOPHEN AND CODEINE',
#  'ACETAMINOPHEN AND CODEINE',
#  'POVIDONE IODINE',
#  'POVIDONE IODINE',
#  'POVIDONE IODINE',
#  'POVIDONE IODINE',
#  'POVIDONE IODINE',
#  'POVIDONE IODINE',
#  'NITROFURANTOIN MONOHYDRAT',
#  'NITROFURANTOIN MONOHYDRAT',
#  'NITROFURANTOIN MONOHYDRAT',
#  'NITROFURANTOIN MONOHYDRAT',
#  'NITROFURANTOIN MONOHYDRAT',
#  'POLYVINYL ALCOHOL',
#  'POLYVINYL ALCOHOL',
#  'POLYVINYL ALCOHOL',
#  'POLYVINYL ALCOHOL',
#  'POLYVINYL ALCOHOL',
#  'IBUPROFEN',
#  'IBUPROFEN',
#  'IBUPROFEN',
#  'IBUPROFEN',
#  'IBUPROFEN',
#  'IBUPROFEN',
#  'IBUPROFEN',
#  'IBUPROFEN',
#  'IBUPROFEN',
#  'IBUPROFEN',
#  'IBUPROFEN',
#  'BROSIMUM ACUTIFOLIUM HIMA',
#  'BROSIMUM ACUTIFOLIUM HIMA',
#  'BROSIMUM ACUTIFOLIUM HIMA',
#  'ALCOHOL',
#  'ALCOHOL',
#  'ALCOHOL',
#  'ALCOHOL',
#  'ALCOHOL',
#  'ALCOHOL',
#  'ALCOHOL',
#  'ALCOHOL',
#  'ALCOHOL',
#  'ALCOHOL',
#  'ALCOHOL',
#  'ALCOHOL',
#  'ALCOHOL',
#  'ALCOHOL',
#  'ALCOHOL',
#  'ALCOHOL',
#  'ALCOHOL',
#  'ALCOHOL',
#  'ALCOHOL',
#  'ALCOHOL',
#  'ALCOHOL',
#  'ALCOHOL',
#  'ACETAMINOPHEN DIPHENHYDRA',
#  'WART REMOVERS',
#  'WART REMOVERS',
#  'WART REMOVERS',
#  'WART REMOVERS',
#  'WART REMOVERS',
#  'WART REMOVERS',
#  'WART REMOVERS',
#  'HYDROCODONE BITARTRATE AN',
#  'HYDROCODONE BITARTRATE AN',
#  'HYDROCODONE BITARTRATE AN',
#  'HYDROCODONE BITARTRATE AN',
#  'HYDROCODONE BITARTRATE AN',
#  'LORAZEPAM',
#  'LORAZEPAM',
#  'LORAZEPAM',
#  'LORAZEPAM',
#  'LORAZEPAM',
#  'LORAZEPAM',
#  'LORAZEPAM',
#  'LORAZEPAM',
#  'LORAZEPAM',
#  'LORAZEPAM',
#  'LORAZEPAM',
#  'LORAZEPAM',
#  'LORAZEPAM',
#  'LORAZEPAM',
#  'LORAZEPAM',
#  'LORAZEPAM',
#  'LORAZEPAM',
#  'LORAZEPAM',
#  'LORAZEPAM',
#  'LORAZEPAM',
#  'CALCIUM CARBONATE',
#  'CALCIUM CARBONATE',
#  'CALCIUM CARBONATE',
#  'CALCIUM CARBONATE',
#  'CALCIUM CARBONATE',
#  'CALCIUM CARBONATE',
#  'CALCIUM CARBONATE',
#  'CALCIUM CARBONATE',
#  'CALCIUM CARBONATE',
#  'CALCIUM CARBONATE',
#  'CALCIUM CARBONATE',
#  'CALCIUM CARBONATE',
#  'CALCIUM CARBONATE',
#  'CALCIUM CARBONATE',
#  'CALCIUM CARBONATE',
#  'CALCIUM CARBONATE',
#  'CIDOFOVIR ANHYDROUS',
#  'CIDOFOVIR ANHYDROUS',
#  'CIDOFOVIR ANHYDROUS',
#  'CIDOFOVIR ANHYDROUS',
#  'ADENOSINUM CYCLOPHOSPHORI',
#  'QUERCUS ROBUR WHOLE',
#  'QUERCUS ROBUR WHOLE',
#  'QUERCUS ROBUR WHOLE',
#  'QUERCUS ROBUR WHOLE',
#  'QUERCUS ROBUR WHOLE',
#  'QUERCUS ROBUR WHOLE',
#  'QUERCUS ROBUR WHOLE',
#  'QUERCUS ROBUR WHOLE',
#  'METHYLPREDNISOLONE ACETAT',
#  'METHYLPREDNISOLONE ACETAT',
#  'METHYLPREDNISOLONE ACETAT',
#  'METHYLPREDNISOLONE ACETAT',
#  'METHYLPREDNISOLONE ACETAT',
#  'EUPATORIUM PERFOLIATUM FL',
#  'EUPATORIUM PERFOLIATUM FL',
#  'EUPATORIUM PERFOLIATUM FL',
#  'BRIMONIDINE TARTRATE',
#  'BRIMONIDINE TARTRATE',
#  'BRIMONIDINE TARTRATE',
#  'BRIMONIDINE TARTRATE',
#  'BRIMONIDINE TARTRATE',
#  'BRIMONIDINE TARTRATE',
#  'BRIMONIDINE TARTRATE',
#  'BRIMONIDINE TARTRATE',
#  'BRIMONIDINE TARTRATE',
#  'BRIMONIDINE TARTRATE',
#  'PINUS SYLVESTRIS WHOLE',
#  'PINUS SYLVESTRIS WHOLE',
#  'PINUS SYLVESTRIS WHOLE',
#  'PINUS SYLVESTRIS WHOLE',
#  'PINUS SYLVESTRIS WHOLE',
#  'PINUS SYLVESTRIS WHOLE',
#  'METHYLCELLULOSE',
#  'METHYLCELLULOSE',
#  'METHYLCELLULOSE',
#  'ACETAMINOPHEN DEXTROMETHO',
#  'SALIX ALBA WHOLE',
#  'SALIX ALBA WHOLE',
#  'SALIX ALBA WHOLE',
#  'SALIX ALBA WHOLE',
#  'SALIX ALBA WHOLE',
#  'SALIX ALBA WHOLE',
#  'SALIX ALBA WHOLE',
#  'SALIX ALBA WHOLE',
#  'SALIX ALBA WHOLE',
#  'SALIX ALBA WHOLE',
#  'SALIX ALBA WHOLE',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'MELATONIN',
#  'BUPRENORPHINE HYDROCHLORI',
#  'BUPRENORPHINE HYDROCHLORI',
#  'BUPRENORPHINE HYDROCHLORI',
#  'BUPRENORPHINE HYDROCHLORI',
#  'BUPRENORPHINE HYDROCHLORI',
#  'BUPRENORPHINE HYDROCHLORI',
#  'BUPRENORPHINE HYDROCHLORI',
#  'DOPAMINE HYDROCHLORIDE',
#  'DOPAMINE HYDROCHLORIDE',
#  'DOPAMINE HYDROCHLORIDE',
#  'DOPAMINE HYDROCHLORIDE',
#  'DOPAMINE HYDROCHLORIDE',
#  'DOPAMINE HYDROCHLORIDE',
#  'DOPAMINE HYDROCHLORIDE',
#  'DOPAMINE HYDROCHLORIDE',
#  'DOPAMINE HYDROCHLORIDE',
#  'DOPAMINE HYDROCHLORIDE',
#  'DOPAMINE HYDROCHLORIDE',
#  'DOPAMINE HYDROCHLORIDE',
#  'DOPAMINE HYDROCHLORIDE',
#  'DOPAMINE HYDROCHLORIDE',
#  'DOPAMINE HYDROCHLORIDE',
#  'DOPAMINE HYDROCHLORIDE',
#  'DOPAMINE HYDROCHLORIDE',
#  'DOPAMINE HYDROCHLORIDE',
#  'DOPAMINE HYDROCHLORIDE',
#  'DOPAMINE HYDROCHLORIDE',
#  'DOPAMINE HYDROCHLORIDE',
#  'DOPAMINE HYDROCHLORIDE',
#  'DOPAMINE HYDROCHLORIDE',
#  'DOPAMINE HYDROCHLORIDE',
#  'DOPAMINE HYDROCHLORIDE',
#  'PROMETHAZINE',
#  'PROMETHAZINE',
#  'PROMETHAZINE',
#  'PROMETHAZINE',
#  'PROMETHAZINE',
#  'PROMETHAZINE',
#  'PROMETHAZINE',
#  'PROMETHAZINE',
#  'PROMETHAZINE',
#  'PROMETHAZINE',
#  'PROMETHAZINE',
#  'PROMETHAZINE',
#  'PROMETHAZINE',
#  'PROMETHAZINE',
#  'PROMETHAZINE',
#  'PROMETHAZINE',
#  'PROMETHAZINE',
#  'DEXTROAMPHETAMINE SULFATE',
#  'DEXTROAMPHETAMINE SULFATE',
#  'DICLOFENAC SODIUM',
#  'DICLOFENAC SODIUM',
#  'DICLOFENAC SODIUM',
#  'DICLOFENAC SODIUM',
#  'DICLOFENAC SODIUM',
#  'DICLOFENAC SODIUM',
#  'DICLOFENAC SODIUM',
#  'DICLOFENAC SODIUM',
#  'SODIUM PHOSPHATE MONOBASI',
#  'SODIUM PHOSPHATE MONOBASI',
#  'SODIUM PHOSPHATE MONOBASI',
#  'SODIUM PHOSPHATE MONOBASI',
#  'DACLIZUMAB',
#  'DACLIZUMAB',
#  'DACLIZUMAB',
#  'DACLIZUMAB',
#  'DACLIZUMAB',
#  'DACLIZUMAB',
#  'DACLIZUMAB',
#  'DACLIZUMAB',
#  'DACLIZUMAB',
#  'DACLIZUMAB',
#  'DACLIZUMAB',
#  'DACLIZUMAB',
#  'DACLIZUMAB',
#  'DACLIZUMAB',
#  'DACLIZUMAB',
#  'DACLIZUMAB',
#  'DACLIZUMAB',
#  'DACLIZUMAB',
#  'DACLIZUMAB',
#  'DACLIZUMAB',
#  'DACLIZUMAB',
#  'VALGANCICLOVIR HYDROCHLOR',
#  'VALGANCICLOVIR HYDROCHLOR',
#  'FOLLICULINUM OOPHORINUM',
#  'FOLLICULINUM OOPHORINUM',
#  'ETOMIDATE INJECTION',
#  'ETOMIDATE INJECTION',
#  'ETOMIDATE INJECTION',
#  'ETOMIDATE INJECTION',
#  'ETOMIDATE INJECTION',
#  'ETOMIDATE INJECTION',
#  'ETOMIDATE INJECTION',
#  'OXACILLIN SODIUM',
#  'OXACILLIN SODIUM',
#  'OXACILLIN SODIUM',
#  'OXACILLIN SODIUM',
#  'OXACILLIN SODIUM',
#  'OXACILLIN SODIUM',
#  'OXACILLIN SODIUM',
#  'OXACILLIN SODIUM',
#  'OXACILLIN SODIUM',
#  'OXACILLIN SODIUM',
#  'OXACILLIN SODIUM',
#  'INTERFERON ALFA-2A',
#  'INTERFERON ALFA-2A',
#  'INTERFERON ALFA-2A',
#  'INTERFERON ALFA-2A',
#  'INTERFERON ALFA-2A',
#  'INTERFERON ALFA-2A',
#  'INTERFERON ALFA-2A',
#  'SODIUM CITRATE',
#  'SODIUM CITRATE',
#  'SODIUM CITRATE',
#  'SODIUM CITRATE',
#  'SODIUM CITRATE',
#  'SODIUM CITRATE',
#  'SODIUM CITRATE',
#  'SODIUM CITRATE',
#  'SODIUM CITRATE',
#  'SODIUM CITRATE',
#  'SODIUM CITRATE',
#  'SODIUM CITRATE',
#  'SODIUM CITRATE',
#  'SODIUM CITRATE',
#  'SODIUM CITRATE',
#  'FENTANYL CITRATE',
#  'FENTANYL CITRATE',
#  'FENTANYL CITRATE',
#  'FENTANYL CITRATE',
#  'FENTANYL CITRATE',
#  'DOXYCLYCLINE HYCLATE',
#  'DOXYCLYCLINE HYCLATE',
#  'DOXYCLYCLINE HYCLATE',
#  'ULEX EUROPAEUS WHOLE',
#  'ULEX EUROPAEUS WHOLE',
#  'ULEX EUROPAEUS WHOLE',
#  'ULEX EUROPAEUS WHOLE',
#  'ULEX EUROPAEUS WHOLE',
#  'LOXAPINE',
#  'LOXAPINE',
#  'LOXAPINE',
#  'LOXAPINE',
#  'LOXAPINE',
#  'LOXAPINE',
#  'LOXAPINE',
#  ...]

# %%
gen_name_dict = dict(zip(gen_name_list, cluster_list))

# %%
result = [gen_name_dict[w[:char_lim]] for w in generic_name_unique if w[:char_lim] in gen_name_dict.keys()]

# %%
with open("./progress/wrangled/generic_name_unique.txt", "rb") as fp:   # Unpickling
    generic_name_unique = pickle.load(fp)

# %%
def entry_condenser(unique_col, char_lim = None):
    """
    Takes in a list of unique column entries and returns a dictionary to convert a col to lower-d space
    """
    # https://stats.stackexchange.com/questions/123060/clustering-a-long-list-of-strings-words-into-similarity-groups
    words_og = unique_col

    # Cut off all but the first set of characters
    if char_lim is not None:
        words = [w[:char_lim] for w in words_og]
    else:
        words = words_og

    # Get similarity matrix
    words = np.asarray(words) 
    lev_similarity = -1*np.array([[distance(w1,w2) for w1 in words] for w2 in words])

    # Fit an affinity model
    affprop = sklearn.cluster.AffinityPropagation(affinity="precomputed", damping=0.5)
    affprop.fit(lev_similarity)

    # Group the words with their respective clusters
    cluster_list = []
    gen_name_list = []
    for cluster_id in np.unique(affprop.labels_):
        exemplar = words[affprop.cluster_centers_indices_[cluster_id]]
        cluster = np.unique(words[np.nonzero(affprop.labels_==cluster_id)])
        cluster_str = ", ".join(cluster)
        for name in cluster:
            cluster_list.append(exemplar)
            gen_name_list.append(name)
            
    gen_name_dict = dict(zip(gen_name_list, cluster_list))
    
    return gen_name_dict
